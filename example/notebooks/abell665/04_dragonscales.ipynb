# %%
/bin/rm -rf dragon_scales
mkdir dragon_scales
cd dragon_scales

ln -s ../sunset-in-atlantis.sao ./
ln -s ../sm.flux ./

# %%
punlearn dragon_scales

# %%
plist dragon_scales
# Out:
# Parameters for /home/kjg/cxcds_param4/dragon_scales.par
#
#         infile =                  Input image
#         radius =                  Input radius map file or single number
#        outfile =                  Output map
#        (binimg = )                Output image file
#         (shape = circle)          Shape of mask regions
#      (gradient = yes)             Rotate shape to match local gradient?
#       (verbose = 1)               Tool chatter level
#       (clobber = no)              Remove outfile if it already exists?
#          (mode = ql)

# %%
pget dragon_scales shape.p_min
# Out:
# circle|box|diamond|hexagon|triangle|itriangle

# %%
dragon_scales sm.flux radius=30 outfile=dragon_30px.map binimg=dragon_30px.img shape=hex grad+ clob+
# Out:
# dragon_scales
#           infile = sm.flux
#           radius = 30
#          outfile = dragon_30px.map
#           binimg = dragon_30px.img
#            shape = hexagon
#         gradient = yes
#          verbose = 1
#          clobber = yes
#             mode = ql

# %%
###map2reg dragon_30px.map dragon_30px.reg clob+
dmimggrad dragon_30px.map dragon_30px.grad sobel mag clob+

# %%
ds9 -geometry 1500x800 dragon_30px.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask dragon_30px.grad -frame new -tile -nomask \
     dragon_30px.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask dragon_30px.grad \
    -saveimage png dragon_10px.png -exit

display < dragon_10px.png

# %%
plist merge_too_small
# Out:
# Parameters for /soft/ciao-4.13/contrib/param/merge_too_small.par
#
#         infile =                  Input map
#        outfile =                  Output map
#        (method = counts)          Apply minval threshold to area of region or counts in region?
#       (imgfile = )                Input counts image file, required for method=counts
#        (binimg = )                Optional output image file
#      (minvalue = 0)               Minimum counts or area (logical pixels)
#       (verbose = 0)               Tool chatter level
#       (clobber = no)              Remove outfile if it already exists?
#          (mode = ql)

# %%
merge_too_small infile=dragon_30px.map outfile=dragon_min50cts.map \
  method=counts imgfile=../abell665_broad_thresh.img minvalue=150 verbose=1 clob+
# Out:
# merge_too_small
#           infile = dragon_30px.map
#          outfile = dragon_min50cts.map
#           method = counts
#          imgfile = ../abell665_broad_thresh.img
#           binimg =
#         minvalue = 150
#          verbose = 1
#          clobber = yes
#             mode = ql
#
# Working on mask_id 426 with value 1
# Working on mask_id 443 with value 1
# Working on mask_id 494 with value 1
# Working on mask_id 604 with value 1
# Working on mask_id 694 with value 1
# Working on mask_id 712 with value 1
# Working on mask_id 802 with value 1
# Working on mask_id 811 with value 1
# Working on mask_id 830 with value 1
# Working on mask_id 853 with value 1
# Working on mask_id 944 with value 1
# Working on mask_id 991 with value 1
# Working on mask_id 1012 with value 1
# Working on mask_id 1023 with value 1
# Working on mask_id 1025 with value 1
# Working on mask_id 1039 with value 1
# Working on mask_id 1041 with value 1
# Working on mask_id 1057 with value 1
# Working on mask_id 1062 with value 1
# Working on mask_id 1071 with value 1
# Working on mask_id 1087 with value 1
# Working on mask_id 1104 with value 1
# Working on mask_id 1126 with value 1
# Working on mask_id 1131 with value 1
# Working on mask_id 1140 with value 1
# Working on mask_id 1153 with value 1
# Working on mask_id 1155 with value 1
# Working on mask_id 1168 with value 1
# Working on mask_id 1171 with value 1
# Working on mask_id 1172 with value 1
# Working on mask_id 1176 with value 1
# Working on mask_id 1178 with value 1
# Working on mask_id 1181 with value 1
# Working on mask_id 1186 with value 1
# Working on mask_id 1188 with value 1
# Working on mask_id 1190 with value 1
# Working on mask_id 1194 with value 1
# Working on mask_id 251 with value 2
# Working on mask_id 375 with value 2
# Working on mask_id 390 with value 2
# Working on mask_id 537 with value 2
# Working on mask_id 553 with value 2
# Working on mask_id 563 with value 2
# Working on mask_id 701 with value 2
# Working on mask_id 702 with value 2
# Working on mask_id 722 with value 2
# Working on mask_id 733 with value 2
# Working on mask_id 815 with value 2
# Working on mask_id 827 with value 2
# Working on mask_id 852 with value 2
# Working on mask_id 900 with value 2
# Working on mask_id 902 with value 2
# Working on mask_id 912 with value 2
# Working on mask_id 918 with value 2
# Working on mask_id 948 with value 2
# Working on mask_id 963 with value 2
# Working on mask_id 965 with value 2
# Working on mask_id 995 with value 2
# Working on mask_id 1024 with value 2
# Working on mask_id 1046 with value 2
# Working on mask_id 1063 with value 2
# Working on mask_id 1080 with value 2
# Working on mask_id 1135 with value 2
# Working on mask_id 1145 with value 2
# Working on mask_id 1152 with value 2
# Working on mask_id 1162 with value 2
# Working on mask_id 1184 with value 2
# Working on mask_id 1193 with value 2
# Working on mask_id 1206 with value 2
# Working on mask_id 1212 with value 2
# Working on mask_id 150 with value 3
# Working on mask_id 276 with value 3
# Working on mask_id 438 with value 3
# Working on mask_id 546 with value 3
# Working on mask_id 616 with value 3
# Working on mask_id 877 with value 3
# Working on mask_id 996 with value 3
# Working on mask_id 1013 with value 3
# Working on mask_id 1018 with value 3
# Working on mask_id 1032 with value 3
# Working on mask_id 1040 with value 3
# Working on mask_id 1052 with value 3
# Working on mask_id 1073 with value 3
# Working on mask_id 1091 with value 3
# Working on mask_id 1095 with value 3
# Working on mask_id 1107 with value 3
# Working on mask_id 1133 with value 3
# Working on mask_id 1144 with value 3
# Working on mask_id 1166 with value 3
# Working on mask_id 1170 with value 3
# Working on mask_id 1187 with value 3
# Working on mask_id 662 with value 4
# Working on mask_id 758 with value 4
# Working on mask_id 768 with value 4
# Working on mask_id 860 with value 4
# Working on mask_id 879 with value 4
# Working on mask_id 880 with value 4
# Working on mask_id 901 with value 4
# Working on mask_id 907 with value 4
# Working on mask_id 983 with value 4
# Working on mask_id 989 with value 4
# Working on mask_id 999 with value 4
# Working on mask_id 1000 with value 4
# Working on mask_id 1008 with value 4
# Working on mask_id 1068 with value 4
# Working on mask_id 1121 with value 4
# Working on mask_id 1160 with value 4
# Working on mask_id 1182 with value 4
# Working on mask_id 1192 with value 4
# Working on mask_id 447 with value 5
# Working on mask_id 493 with value 5
# Working on mask_id 686 with value 5
# Working on mask_id 794 with value 5
# Working on mask_id 869 with value 5
# Working on mask_id 950 with value 5
# Working on mask_id 1003 with value 5
# Working on mask_id 1074 with value 5
# Working on mask_id 1094 with value 5
# Working on mask_id 1102 with value 5
# Working on mask_id 1103 with value 5
# Working on mask_id 1151 with value 5
# Working on mask_id 354 with value 6
# Working on mask_id 383 with value 6
# Working on mask_id 423 with value 6
# Working on mask_id 800 with value 6
# Working on mask_id 822 with value 6
# Working on mask_id 1070 with value 6
# Working on mask_id 1075 with value 6
# Working on mask_id 1085 with value 6
# Working on mask_id 1086 with value 6
# Working on mask_id 1125 with value 6
# Working on mask_id 1128 with value 6
# Working on mask_id 1175 with value 6
# Working on mask_id 184 with value 7
# Working on mask_id 828 with value 7
# Working on mask_id 832 with value 7
# Working on mask_id 846 with value 7
# Working on mask_id 872 with value 7
# Working on mask_id 917 with value 7
# Working on mask_id 935 with value 7
# Working on mask_id 969 with value 7
# Working on mask_id 980 with value 7
# Working on mask_id 1093 with value 7
# Working on mask_id 1101 with value 7
# Working on mask_id 690 with value 8
# Working on mask_id 755 with value 8
# Working on mask_id 843 with value 8
# Working on mask_id 905 with value 8
# Working on mask_id 955 with value 8
# Working on mask_id 981 with value 8
# Working on mask_id 1010 with value 8
# Working on mask_id 1097 with value 8
# Working on mask_id 1100 with value 8
# Working on mask_id 1108 with value 8
# Working on mask_id 1113 with value 8
# Working on mask_id 568 with value 9
# Working on mask_id 655 with value 9
# Working on mask_id 747 with value 9
# Working on mask_id 764 with value 9
# Working on mask_id 787 with value 9
# Working on mask_id 923 with value 9
# Working on mask_id 1014 with value 9
# Working on mask_id 1060 with value 9
# Working on mask_id 1065 with value 9
# Working on mask_id 1081 with value 9
# Working on mask_id 1123 with value 9
# Working on mask_id 1124 with value 9
# Working on mask_id 1209 with value 9
# Working on mask_id 696 with value 10
# Working on mask_id 886 with value 10
# Working on mask_id 914 with value 10
# Working on mask_id 1059 with value 10
# Working on mask_id 1127 with value 10
# Working on mask_id 1149 with value 10
# Working on mask_id 1185 with value 10
# Working on mask_id 368 with value 11
# Working on mask_id 813 with value 11
# Working on mask_id 834 with value 11
# Working on mask_id 939 with value 11
# Working on mask_id 949 with value 11
# Working on mask_id 985 with value 11
# Working on mask_id 998 with value 11
# Working on mask_id 1029 with value 11
# Working on mask_id 1089 with value 11
# Working on mask_id 565 with value 12
# Working on mask_id 574 with value 12
# Working on mask_id 674 with value 12
# Working on mask_id 675 with value 12
# Working on mask_id 725 with value 12
# Working on mask_id 819 with value 12
# Working on mask_id 820 with value 12
# Working on mask_id 1001 with value 12
# Working on mask_id 1141 with value 12
# Working on mask_id 382 with value 13
# Working on mask_id 611 with value 13
# Working on mask_id 689 with value 13
# Working on mask_id 777 with value 13
# Working on mask_id 883 with value 13
# Working on mask_id 920 with value 13
# Working on mask_id 968 with value 13
# Working on mask_id 1033 with value 13
# Working on mask_id 1079 with value 13
# Working on mask_id 763 with value 14
# Working on mask_id 896 with value 14
# Working on mask_id 1026 with value 14
# Working on mask_id 1069 with value 14
# Working on mask_id 1088 with value 14
# Working on mask_id 1129 with value 14
# Working on mask_id 190 with value 15
# Working on mask_id 289 with value 15
# Working on mask_id 306 with value 15
# Working on mask_id 624 with value 15
# Working on mask_id 704 with value 15
# Working on mask_id 718 with value 15
# Working on mask_id 779 with value 15
# Working on mask_id 957 with value 15
# Working on mask_id 1002 with value 15
# Working on mask_id 1138 with value 15
# Working on mask_id 1163 with value 15
# Working on mask_id 509 with value 16
# Working on mask_id 591 with value 16
# Working on mask_id 933 with value 16
# Working on mask_id 946 with value 16
# Working on mask_id 1050 with value 16
# Working on mask_id 1066 with value 16
# Working on mask_id 333 with value 17
# Working on mask_id 335 with value 17
# Working on mask_id 436 with value 17
# Working on mask_id 533 with value 17
# Working on mask_id 535 with value 17
# Working on mask_id 579 with value 17
# Working on mask_id 728 with value 17
# Working on mask_id 897 with value 17
# Working on mask_id 938 with value 17
# Working on mask_id 986 with value 17
# Working on mask_id 1083 with value 17
# Working on mask_id 875 with value 18
# Working on mask_id 881 with value 18
# Working on mask_id 1110 with value 18
# Working on mask_id 352 with value 19
# Working on mask_id 614 with value 19
# Working on mask_id 706 with value 19
# Working on mask_id 785 with value 19
# Working on mask_id 855 with value 19
# Working on mask_id 322 with value 20
# Working on mask_id 625 with value 20
# Working on mask_id 842 with value 20
# Working on mask_id 988 with value 20
# Working on mask_id 1036 with value 20
# Working on mask_id 1047 with value 20
# Working on mask_id 419 with value 21
# Working on mask_id 679 with value 21
# Working on mask_id 927 with value 21
# Working on mask_id 1051 with value 21
# Working on mask_id 1105 with value 21
# Working on mask_id 1111 with value 21
# Working on mask_id 1119 with value 21
# Working on mask_id 558 with value 22
# Working on mask_id 739 with value 22
# Working on mask_id 774 with value 22
# Working on mask_id 821 with value 22
# Working on mask_id 217 with value 23
# Working on mask_id 391 with value 23
# Working on mask_id 458 with value 23
# Working on mask_id 596 with value 23
# Working on mask_id 682 with value 23
# Working on mask_id 854 with value 23
# Working on mask_id 1115 with value 23
# Working on mask_id 1130 with value 23
# Working on mask_id 532 with value 24
# Working on mask_id 580 with value 24
# Working on mask_id 729 with value 24
# Working on mask_id 735 with value 24
# Working on mask_id 921 with value 24
# Working on mask_id 984 with value 24
# Working on mask_id 997 with value 24
# Working on mask_id 1015 with value 24
# Working on mask_id 1099 with value 24
# Working on mask_id 301 with value 25
# Working on mask_id 554 with value 25
# Working on mask_id 657 with value 25
# Working on mask_id 823 with value 25
# Working on mask_id 895 with value 25
# Working on mask_id 1049 with value 25
# Working on mask_id 287 with value 26
# Working on mask_id 387 with value 26
# Working on mask_id 396 with value 26
# Working on mask_id 644 with value 26
# Working on mask_id 665 with value 26
# Working on mask_id 893 with value 26
# Working on mask_id 956 with value 26
# Working on mask_id 1048 with value 26
# Working on mask_id 793 with value 27
# Working on mask_id 859 with value 27
# Working on mask_id 302 with value 28
# Working on mask_id 473 with value 28
# Working on mask_id 1030 with value 28
# Working on mask_id 1037 with value 28
# Working on mask_id 1118 with value 28
# Working on mask_id 503 with value 29
# Working on mask_id 592 with value 29
# Working on mask_id 720 with value 29
# Working on mask_id 730 with value 29
# Working on mask_id 814 with value 29
# Working on mask_id 867 with value 29
# Working on mask_id 885 with value 29
# Working on mask_id 891 with value 29
# Working on mask_id 1072 with value 29
# Working on mask_id 243 with value 30
# Working on mask_id 332 with value 30
# Working on mask_id 378 with value 30
# Working on mask_id 388 with value 30
# Working on mask_id 468 with value 30
# Working on mask_id 620 with value 30
# Working on mask_id 265 with value 31
# Working on mask_id 666 with value 31
# Working on mask_id 713 with value 31
# Working on mask_id 870 with value 31
# Working on mask_id 911 with value 31
# Working on mask_id 960 with value 31
# Working on mask_id 974 with value 31
# Working on mask_id 1022 with value 31
# Working on mask_id 101 with value 32
# Working on mask_id 336 with value 32
# Working on mask_id 367 with value 32
# Working on mask_id 547 with value 32
# Working on mask_id 581 with value 32
# Working on mask_id 746 with value 32
# Working on mask_id 839 with value 32
# Working on mask_id 435 with value 33
# Working on mask_id 677 with value 33
# Working on mask_id 708 with value 33
# Working on mask_id 1005 with value 33
# Working on mask_id 1120 with value 33
# Working on mask_id 475 with value 34
# Working on mask_id 569 with value 34
# Working on mask_id 771 with value 34
# Working on mask_id 884 with value 34
# Working on mask_id 909 with value 34
# Working on mask_id 990 with value 34
# Working on mask_id 247 with value 35
# Working on mask_id 395 with value 35
# Working on mask_id 626 with value 35
# Working on mask_id 669 with value 35
# Working on mask_id 748 with value 35
# Working on mask_id 975 with value 35
# Working on mask_id 318 with value 36
# Working on mask_id 571 with value 36
# Working on mask_id 577 with value 36
# Working on mask_id 609 with value 36
# Working on mask_id 926 with value 36
# Working on mask_id 1028 with value 36
# Working on mask_id 410 with value 37
# Working on mask_id 498 with value 37
# Working on mask_id 915 with value 37
# Working on mask_id 319 with value 38
# Working on mask_id 600 with value 38
# Working on mask_id 799 with value 38
# Working on mask_id 851 with value 38
# Working on mask_id 864 with value 38
# Working on mask_id 215 with value 39
# Working on mask_id 271 with value 39
# Working on mask_id 402 with value 39
# Working on mask_id 513 with value 39
# Working on mask_id 664 with value 39
# Working on mask_id 710 with value 39
# Working on mask_id 908 with value 39
# Working on mask_id 924 with value 39
# Working on mask_id 961 with value 39
# Working on mask_id 155 with value 40
# Working on mask_id 340 with value 40
# Working on mask_id 564 with value 40
# Working on mask_id 1045 with value 40
# Working on mask_id 284 with value 41
# Working on mask_id 325 with value 41
# Working on mask_id 474 with value 41
# Working on mask_id 542 with value 41
# Working on mask_id 673 with value 41
# Working on mask_id 684 with value 41
# Working on mask_id 731 with value 41
# Working on mask_id 789 with value 41
# Working on mask_id 1156 with value 41
# Working on mask_id 427 with value 42
# Working on mask_id 508 with value 42
# Working on mask_id 937 with value 42
# Working on mask_id 958 with value 42
# Working on mask_id 605 with value 43
# Working on mask_id 847 with value 43
# Working on mask_id 878 with value 43
# Working on mask_id 994 with value 43
# Working on mask_id 139 with value 44
# Working on mask_id 374 with value 44
# Working on mask_id 589 with value 44
# Working on mask_id 607 with value 44
# Working on mask_id 732 with value 44
# Working on mask_id 806 with value 44
# Working on mask_id 505 with value 45
# Working on mask_id 765 with value 45
# Working on mask_id 783 with value 45
# Working on mask_id 951 with value 45
# Working on mask_id 992 with value 45
# Working on mask_id 344 with value 46
# Working on mask_id 392 with value 46
# Working on mask_id 548 with value 46
# Working on mask_id 709 with value 46
# Working on mask_id 760 with value 46
# Working on mask_id 833 with value 46
# Working on mask_id 857 with value 46
# Working on mask_id 1058 with value 46
# Working on mask_id 97 with value 47
# Working on mask_id 566 with value 47
# Working on mask_id 717 with value 47
# Working on mask_id 941 with value 47
# Working on mask_id 1077 with value 47
# Working on mask_id 1082 with value 47
# Working on mask_id 645 with value 48
# Working on mask_id 862 with value 48
# Working on mask_id 863 with value 48
# Working on mask_id 1007 with value 48
# Working on mask_id 1035 with value 48
# Working on mask_id 138 with value 49
# Working on mask_id 233 with value 49
# Working on mask_id 263 with value 49
# Working on mask_id 1143 with value 49
# Working on mask_id 445 with value 50
# Working on mask_id 916 with value 50
# Working on mask_id 978 with value 50
# Working on mask_id 464 with value 51
# Working on mask_id 506 with value 51
# Working on mask_id 525 with value 51
# Working on mask_id 652 with value 51
# Working on mask_id 703 with value 51
# Working on mask_id 116 with value 52
# Working on mask_id 146 with value 52
# Working on mask_id 268 with value 52
# Working on mask_id 668 with value 52
# Working on mask_id 707 with value 52
# Working on mask_id 780 with value 52
# Working on mask_id 786 with value 52
# Working on mask_id 1054 with value 52
# Working on mask_id 202 with value 53
# Working on mask_id 894 with value 53
# Working on mask_id 453 with value 54
# Working on mask_id 687 with value 54
# Working on mask_id 976 with value 54
# Working on mask_id 1043 with value 54
# Working on mask_id 501 with value 55
# Working on mask_id 769 with value 55
# Working on mask_id 850 with value 55
# Working on mask_id 249 with value 56
# Working on mask_id 315 with value 56
# Working on mask_id 646 with value 56
# Working on mask_id 982 with value 56
# Working on mask_id 987 with value 56
# Working on mask_id 200 with value 57
# Working on mask_id 227 with value 57
# Working on mask_id 286 with value 57
# Working on mask_id 371 with value 57
# Working on mask_id 922 with value 57
# Working on mask_id 1019 with value 57
# Working on mask_id 228 with value 58
# Working on mask_id 282 with value 58
# Working on mask_id 583 with value 58
# Working on mask_id 585 with value 58
# Working on mask_id 647 with value 58
# Working on mask_id 658 with value 58
# Working on mask_id 740 with value 58
# Working on mask_id 952 with value 58
# Working on mask_id 348 with value 59
# Working on mask_id 428 with value 59
# Working on mask_id 452 with value 59
# Working on mask_id 560 with value 59
# Working on mask_id 727 with value 59
# Working on mask_id 845 with value 59
# Working on mask_id 899 with value 59
# Working on mask_id 929 with value 59
# Working on mask_id 945 with value 59
# Working on mask_id 993 with value 59
# Working on mask_id 384 with value 60
# Working on mask_id 736 with value 60
# Working on mask_id 801 with value 60
# Working on mask_id 874 with value 60
# Working on mask_id 304 with value 61
# Working on mask_id 393 with value 61
# Working on mask_id 457 with value 61
# Working on mask_id 617 with value 61
# Working on mask_id 724 with value 61
# Working on mask_id 1021 with value 61
# Working on mask_id 1159 with value 61
# Working on mask_id 341 with value 62
# Working on mask_id 432 with value 62
# Working on mask_id 530 with value 62
# Working on mask_id 214 with value 63
# Working on mask_id 316 with value 63
# Working on mask_id 552 with value 63
# Working on mask_id 556 with value 63
# Working on mask_id 593 with value 63
# Working on mask_id 906 with value 63
# Working on mask_id 50 with value 64
# Working on mask_id 551 with value 64
# Working on mask_id 697 with value 64
# Working on mask_id 809 with value 64
# Working on mask_id 144 with value 65
# Working on mask_id 582 with value 65
# Working on mask_id 404 with value 66
# Working on mask_id 639 with value 66
# Working on mask_id 211 with value 67
# Working on mask_id 545 with value 67
# Working on mask_id 610 with value 67
# Working on mask_id 715 with value 67
# Working on mask_id 500 with value 68
# Working on mask_id 745 with value 68
# Working on mask_id 888 with value 68
# Working on mask_id 534 with value 69
# Working on mask_id 868 with value 69
# Working on mask_id 515 with value 70
# Working on mask_id 252 with value 71
# Working on mask_id 480 with value 71
# Working on mask_id 499 with value 71
# Working on mask_id 759 with value 71
# Working on mask_id 1142 with value 71
# Working on mask_id 213 with value 72
# Working on mask_id 373 with value 72
# Working on mask_id 536 with value 72
# Working on mask_id 575 with value 72
# Working on mask_id 835 with value 72
# Working on mask_id 849 with value 72
# Working on mask_id 882 with value 72
# Working on mask_id 273 with value 73
# Working on mask_id 298 with value 73
# Working on mask_id 661 with value 73
# Working on mask_id 766 with value 73
# Working on mask_id 792 with value 73
# Working on mask_id 307 with value 74
# Working on mask_id 456 with value 74
# Working on mask_id 561 with value 74
# Working on mask_id 630 with value 74
# Working on mask_id 603 with value 75
# Working on mask_id 660 with value 75
# Working on mask_id 928 with value 75
# Working on mask_id 1009 with value 75
# Working on mask_id 1027 with value 75
# Working on mask_id 258 with value 76
# Working on mask_id 275 with value 76
# Working on mask_id 762 with value 76
# Working on mask_id 817 with value 76
# Working on mask_id 825 with value 76
# Working on mask_id 1098 with value 76
# Working on mask_id 349 with value 77
# Working on mask_id 716 with value 77
# Working on mask_id 788 with value 77
# Working on mask_id 147 with value 78
# Working on mask_id 177 with value 78
# Working on mask_id 812 with value 78
# Working on mask_id 107 with value 79
# Working on mask_id 409 with value 79
# Working on mask_id 635 with value 79
# Working on mask_id 756 with value 79
# Working on mask_id 1067 with value 80
# Working on mask_id 290 with value 81
# Working on mask_id 442 with value 81
# Working on mask_id 650 with value 81
# Working on mask_id 317 with value 82
# Working on mask_id 439 with value 82
# Working on mask_id 578 with value 82
# Working on mask_id 741 with value 82
# Working on mask_id 871 with value 82
# Working on mask_id 979 with value 82
# Working on mask_id 281 with value 83
# Working on mask_id 372 with value 83
# Working on mask_id 437 with value 83
# Working on mask_id 511 with value 83
# Working on mask_id 803 with value 83
# Working on mask_id 359 with value 84
# Working on mask_id 685 with value 84
# Working on mask_id 698 with value 84
# Working on mask_id 865 with value 84
# Working on mask_id 193 with value 85
# Working on mask_id 331 with value 85
# Working on mask_id 407 with value 85
# Working on mask_id 490 with value 85
# Working on mask_id 919 with value 85
# Working on mask_id 942 with value 85
# Working on mask_id 953 with value 85
# Working on mask_id 840 with value 86
# Working on mask_id 925 with value 86
# Working on mask_id 502 with value 87
# Working on mask_id 523 with value 87
# Working on mask_id 567 with value 87
# Working on mask_id 489 with value 88
# Working on mask_id 539 with value 88
# Working on mask_id 339 with value 89
# Working on mask_id 521 with value 89
# Working on mask_id 544 with value 89
# Working on mask_id 678 with value 89
# Working on mask_id 121 with value 90
# Working on mask_id 167 with value 90
# Working on mask_id 209 with value 90
# Working on mask_id 632 with value 90
# Working on mask_id 334 with value 91
# Working on mask_id 667 with value 91
# Working on mask_id 681 with value 91
# Working on mask_id 1017 with value 91
# Working on mask_id 327 with value 92
# Working on mask_id 491 with value 92
# Working on mask_id 516 with value 93
# Working on mask_id 791 with value 93
# Working on mask_id 932 with value 93
# Working on mask_id 279 with value 94
# Working on mask_id 386 with value 94
# Working on mask_id 737 with value 94
# Working on mask_id 816 with value 94
# Working on mask_id 529 with value 95
# Working on mask_id 296 with value 96
# Working on mask_id 587 with value 96
# Working on mask_id 621 with value 96
# Working on mask_id 309 with value 97
# Working on mask_id 326 with value 97
# Working on mask_id 476 with value 97
# Working on mask_id 559 with value 97
# Working on mask_id 618 with value 98
# Working on mask_id 672 with value 98
# Working on mask_id 797 with value 98
# Working on mask_id 220 with value 99
# Working on mask_id 303 with value 99
# Working on mask_id 351 with value 99
# Working on mask_id 418 with value 99
# Working on mask_id 826 with value 99
# Working on mask_id 278 with value 100
# Working on mask_id 726 with value 100
# Working on mask_id 781 with value 100
# Working on mask_id 784 with value 100
# Working on mask_id 798 with value 100
# Working on mask_id 292 with value 101
# Working on mask_id 369 with value 101
# Working on mask_id 676 with value 101
# Working on mask_id 399 with value 102
# Working on mask_id 608 with value 102
# Working on mask_id 700 with value 102
# Working on mask_id 721 with value 102
# Working on mask_id 887 with value 102
# Working on mask_id 964 with value 102
# Working on mask_id 412 with value 103
# Working on mask_id 761 with value 103
# Working on mask_id 836 with value 103
# Working on mask_id 186 with value 104
# Working on mask_id 526 with value 104
# Working on mask_id 629 with value 104
# Working on mask_id 648 with value 104
# Working on mask_id 767 with value 104
# Working on mask_id 775 with value 104
# Working on mask_id 206 with value 105
# Working on mask_id 240 with value 105
# Working on mask_id 433 with value 105
# Working on mask_id 1004 with value 105
# Working on mask_id 189 with value 106
# Working on mask_id 594 with value 107
# Working on mask_id 749 with value 107
# Working on mask_id 705 with value 108
# Working on mask_id 757 with value 108
# Working on mask_id 103 with value 109
# Working on mask_id 212 with value 109
# Working on mask_id 510 with value 109
# Working on mask_id 550 with value 109
# Working on mask_id 693 with value 109
# Working on mask_id 572 with value 110
# Working on mask_id 370 with value 111
# Working on mask_id 612 with value 111
# Working on mask_id 699 with value 111
# Working on mask_id 1150 with value 111
# Working on mask_id 288 with value 112
# Working on mask_id 903 with value 114
# Working on mask_id 246 with value 115
# Working on mask_id 455 with value 115
# Working on mask_id 627 with value 115
# Working on mask_id 588 with value 116
# Working on mask_id 659 with value 116
# Working on mask_id 910 with value 116
# Working on mask_id 385 with value 117
# Working on mask_id 601 with value 118
# Working on mask_id 904 with value 118
# Working on mask_id 111 with value 119
# Working on mask_id 133 with value 119
# Working on mask_id 540 with value 119
# Working on mask_id 590 with value 119
# Working on mask_id 342 with value 120
# Working on mask_id 557 with value 120
# Working on mask_id 599 with value 120
# Working on mask_id 295 with value 121
# Working on mask_id 397 with value 121
# Working on mask_id 651 with value 122
# Working on mask_id 831 with value 122
# Working on mask_id 83 with value 123
# Working on mask_id 253 with value 123
# Working on mask_id 449 with value 123
# Working on mask_id 844 with value 123
# Working on mask_id 225 with value 124
# Working on mask_id 350 with value 124
# Working on mask_id 195 with value 125
# Working on mask_id 462 with value 125
# Working on mask_id 858 with value 125
# Working on mask_id 970 with value 125
# Working on mask_id 160 with value 126
# Working on mask_id 192 with value 126
# Working on mask_id 199 with value 126
# Working on mask_id 460 with value 127
# Working on mask_id 465 with value 127
# Working on mask_id 173 with value 128
# Working on mask_id 74 with value 129
# Working on mask_id 343 with value 129
# Working on mask_id 444 with value 129
# Working on mask_id 597 with value 129
# Working on mask_id 598 with value 129
# Working on mask_id 866 with value 130
# Working on mask_id 125 with value 131
# Working on mask_id 170 with value 131
# Working on mask_id 234 with value 131
# Working on mask_id 683 with value 131
# Working on mask_id 323 with value 133
# Working on mask_id 570 with value 133
# Working on mask_id 109 with value 134
# Working on mask_id 356 with value 134
# Working on mask_id 431 with value 134
# Working on mask_id 461 with value 134
# Working on mask_id 46 with value 135
# Working on mask_id 235 with value 135
# Working on mask_id 312 with value 135
# Working on mask_id 405 with value 135
# Working on mask_id 450 with value 135
# Working on mask_id 355 with value 136
# Working on mask_id 398 with value 136
# Working on mask_id 492 with value 136
# Working on mask_id 495 with value 136
# Working on mask_id 154 with value 139
# Working on mask_id 169 with value 139
# Working on mask_id 179 with value 139
# Working on mask_id 337 with value 139
# Working on mask_id 64 with value 140
# Working on mask_id 201 with value 140
# Working on mask_id 166 with value 141
# Working on mask_id 197 with value 141
# Working on mask_id 415 with value 141
# Working on mask_id 108 with value 142
# Working on mask_id 467 with value 144
# Working on mask_id 967 with value 145
# Working on mask_id 389 with value 146
# Working on mask_id 890 with value 146
# Working on mask_id 424 with value 147
# Working on mask_id 615 with value 147
# Working on mask_id 947 with value 147
# Working on mask_id 417 with value 148
# Working on mask_id 362 with value 149
# Working on mask_id 1090 with value 149
# Working on mask_id 196 with value 150
# Working on mask_id 429 with value 150
# Working on mask_id 434 with value 150

# %%
plist dmmaskbin
# Out:
# Parameters for /home/kjg/cxcds_param4/dmmaskbin.par
#
#         infile = sm.flux          Input image to be binned
#       maskfile = dragon_min50cts.map Binning mask
#        outfile = dragon_min50cts.img Output file
#       (errfile = )                Input error file to compute SNR
#       (snrfile = )                Output SNR file
#       (verbose = 0)               Tool chatter level
#       (clobber = no)              Remove files if they exist?
#          (mode = ql)

# %%
dmmaskbin sm.flux dragon_min50cts.map dragon_min50cts.img clob+
dmimggrad dragon_min50cts.map dragon_min50cts.grad sobel mag clob+

# %%
ds9 -geometry 1500x800 dragon_min50cts.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask dragon_30px.grad -frame new -tile -nomask \
     dragon_min50cts.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask dragon_30px.grad \
    -saveimage png dragon_50cts.png -exit

display < dragon_50cts.png

# %%
plist statmap
# Out:
# Parameters for /home/kjg/cxcds_param4/statmap.par
#
#         infile =                  Input event file
#        mapfile =                  Input map file
#        outfile =                  Output file name
#        (column = energy)          Column name to compute statistics
#     (statistic = median)          Which statistic to compute?
#       (clobber = no)              Remove output file if it already exists?
#       (verbose = 1)               Amount of tool chatter
#          (mode = ql)

# %%
statmap "../acisf13201_repro_evt2.fits[energy=500:7000]" \
  dragon_min50cts.map counts.map col=time stat=count clob+ mode=h
# Out:
# statmap
#           infile = ../acisf13201_repro_evt2.fits[energy=500:7000]
#          mapfile = dragon_min50cts.map
#          outfile = counts.map
#           column = time
#        statistic = count
#          clobber = yes
#          verbose = 1
#             mode = h

# %%
ds9 counts.map

# %%
cd dragon_scales
