# %%
punlearn dmellipse
plist dmellipse
# Out:
# Parameters for /home/kjg/cxcds_param4/dmellipse.par
#
#         infile =                  Input image file
#        outfile =                  Output region file
#       fraction =                  Ellipse at what fraction(s)
#         (shape = ellipse)         Shape of region
#    (x_centroid = INDEF)           Default X-centroid to use (physical coords)
#    (y_centroid = INDEF)           Default Y-centroid to use (physical coords)
#         (angle = INDEF)           Default angle [deg]
#   (ellipticity = INDEF)           Default ellipticity
#          (xcol = )                X column name from input table
#          (ycol = )                Y column name from input table
#          (zcol = )                Optional Z column name from input table
#  (fix_centroid = no)              Fix centroid?
#     (fix_angle = no)              Fix angle?
# (fix_ellipticity = no)              Fix ellipticity?
#     (tolerance = 0.001)           Tolerance on fraction
#       (minstep = 0.001)           Minimum step size [pixels]
#       (maxwalk = 10)              Maximum number of equal-fraction walks
#          (step = 1)               Initial step size [pixels]
#     (normalize = yes)             Normalize by sum of pixels
#       (clobber = no)              Remove outfile if it exists
#       (verbose = 0)               Tool chatter level
#          (mode = ql)

# %%
dmellipse abell665.flux.asm \
  ellipse.reg fraction=lgrid"(0.025:1.0:0.025)" \
  step=500 clob+ verb=2 \
  x_cen="4011.5" y_cen="4029.5" fix_cen-
# Out:
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.025	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.025	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.025	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.025	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=30.0061	frac=0.0875839	input_frac=0.025	dir=-1	step=62.5
# state=-1	centroid=(4089.9,4096.99)	ellipticity=1.32795	angle=62.2942	radius=61.2561	frac=0.00977562	input_frac=0.025	dir=1	step=31.25
# state=-1	centroid=(4087.63,4092.47)	ellipticity=1.39418	angle=62.9848	radius=45.6311	frac=0.0388699	input_frac=0.025	dir=-1	step=15.625
# state=-1	centroid=(4086.62,4089.69)	ellipticity=1.44734	angle=64.6842	radius=53.4436	frac=0.0215987	input_frac=0.025	dir=1	step=7.8125
# state=-1	centroid=(4085.03,4086.07)	ellipticity=1.50843	angle=65.5179	radius=49.5374	frac=0.0288769	input_frac=0.025	dir=-1	step=3.90625
# state=0	centroid=(4083.61,4082.64)	ellipticity=1.56308	angle=65.9052	radius=49.5374	frac=0.0240912	input_frac=0.025	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.05	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.05	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.05	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.05	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=30.0061	frac=0.0875839	input_frac=0.05	dir=-1	step=62.5
# state=-1	centroid=(4089.9,4096.99)	ellipticity=1.32795	angle=62.2942	radius=61.2561	frac=0.00977562	input_frac=0.05	dir=1	step=31.25
# state=-1	centroid=(4087.63,4092.47)	ellipticity=1.39418	angle=62.9848	radius=92.5061	frac=0.0388699	input_frac=0.05	dir=1	step=31.25
# state=-1	centroid=(4082.13,4081.74)	ellipticity=1.48258	angle=64.3342	radius=76.8811	frac=0.0831008	input_frac=0.05	dir=-1	step=15.625
# state=-1	centroid=(4078.51,4074.09)	ellipticity=1.56854	angle=65.6446	radius=61.2561	frac=0.0601337	input_frac=0.05	dir=-1	step=15.625
# state=-1	centroid=(4076.4,4068.6)	ellipticity=1.64238	angle=65.9982	radius=69.0686	frac=0.0388526	input_frac=0.05	dir=1	step=7.8125
# state=-1	centroid=(4074.02,4062.44)	ellipticity=1.69182	angle=66.7321	radius=76.8811	frac=0.0480696	input_frac=0.05	dir=1	step=7.8125
# state=-1	centroid=(4072.05,4056.9)	ellipticity=1.6923	angle=68.0114	radius=72.9749	frac=0.0572434	input_frac=0.05	dir=-1	step=3.90625
# state=-1	centroid=(4070.72,4052.3)	ellipticity=1.67397	angle=69.345	radius=69.0686	frac=0.0530075	input_frac=0.05	dir=-1	step=3.90625
# state=0	centroid=(4069.7,4048.54)	ellipticity=1.65174	angle=70.6214	radius=69.0686	frac=0.0499669	input_frac=0.05	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.075	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.075	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.075	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.075	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=30.0061	frac=0.0875839	input_frac=0.075	dir=-1	step=62.5
# state=-1	centroid=(4089.9,4096.99)	ellipticity=1.32795	angle=62.2942	radius=61.2561	frac=0.00977562	input_frac=0.075	dir=1	step=31.25
# state=-1	centroid=(4087.63,4092.47)	ellipticity=1.39418	angle=62.9848	radius=92.5061	frac=0.0388699	input_frac=0.075	dir=1	step=31.25
# state=-1	centroid=(4082.13,4081.74)	ellipticity=1.48258	angle=64.3342	radius=76.8811	frac=0.0831008	input_frac=0.075	dir=-1	step=15.625
# state=-1	centroid=(4078.51,4074.09)	ellipticity=1.56854	angle=65.6446	radius=84.6936	frac=0.0601337	input_frac=0.075	dir=1	step=7.8125
# state=-1	centroid=(4075.36,4066.62)	ellipticity=1.61286	angle=67.3266	radius=92.5061	frac=0.0698907	input_frac=0.075	dir=1	step=7.8125
# state=-1	centroid=(4073.19,4060.55)	ellipticity=1.62096	angle=69.4822	radius=88.5999	frac=0.0794793	input_frac=0.075	dir=-1	step=3.90625
# state=0	centroid=(4071.59,4055.83)	ellipticity=1.61289	angle=71.5464	radius=88.5999	frac=0.075266	input_frac=0.075	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.1	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.1	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.1	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.1	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=157.494	frac=0.0875839	input_frac=0.1	dir=1	step=62.5
# state=-1	centroid=(4084.29,4085.4)	ellipticity=1.36821	angle=63.5735	radius=126.244	frac=0.183212	input_frac=0.1	dir=-1	step=31.25
# state=-1	centroid=(4079.55,4075.16)	ellipticity=1.40518	angle=66.0509	radius=94.9939	frac=0.136983	input_frac=0.1	dir=-1	step=31.25
# state=-1	centroid=(4076.03,4067.4)	ellipticity=1.45998	angle=68.249	radius=110.619	frac=0.0906994	input_frac=0.1	dir=1	step=15.625
# state=-1	centroid=(4073.79,4061.89)	ellipticity=1.47488	angle=70.706	radius=102.806	frac=0.110721	input_frac=0.1	dir=-1	step=7.8125
# state=-1	centroid=(4072.31,4057.57)	ellipticity=1.48753	angle=72.9475	radius=102.806	frac=0.0987806	input_frac=0.1	dir=-1	step=7.8125
# state=-1	centroid=(4071.27,4054.55)	ellipticity=1.49356	angle=74.9489	radius=106.713	frac=0.0987806	input_frac=0.1	dir=1	step=3.90625
# state=-1	centroid=(4070.6,4052.9)	ellipticity=1.48585	angle=76.4916	radius=104.76	frac=0.103468	input_frac=0.1	dir=-1	step=1.95312
# state=-1	centroid=(4070.07,4051.63)	ellipticity=1.48362	angle=77.9465	radius=102.806	frac=0.101068	input_frac=0.1	dir=-1	step=1.95312
# state=-1	centroid=(4069.59,4050.49)	ellipticity=1.48049	angle=79.124	radius=103.783	frac=0.098546	input_frac=0.1	dir=1	step=0.976562
# state=0	centroid=(4069.23,4049.99)	ellipticity=1.47393	angle=80.2175	radius=103.783	frac=0.100091	input_frac=0.1	dir=1	step=0.976562
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.125	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.125	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.125	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.125	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=157.494	frac=0.0875839	input_frac=0.125	dir=1	step=62.5
# state=-1	centroid=(4084.29,4085.4)	ellipticity=1.36821	angle=63.5735	radius=126.244	frac=0.183212	input_frac=0.125	dir=-1	step=31.25
# state=-1	centroid=(4079.55,4075.16)	ellipticity=1.40518	angle=66.0509	radius=94.9939	frac=0.136983	input_frac=0.125	dir=-1	step=31.25
# state=-1	centroid=(4076.03,4067.4)	ellipticity=1.45998	angle=68.249	radius=110.619	frac=0.0906994	input_frac=0.125	dir=1	step=15.625
# state=-1	centroid=(4073.79,4061.89)	ellipticity=1.47488	angle=70.706	radius=126.244	frac=0.110721	input_frac=0.125	dir=1	step=15.625
# state=-1	centroid=(4072.78,4059.75)	ellipticity=1.46472	angle=72.371	radius=118.431	frac=0.130115	input_frac=0.125	dir=-1	step=7.8125
# state=-1	centroid=(4071.92,4057.61)	ellipticity=1.4618	angle=74.01	radius=122.338	frac=0.120565	input_frac=0.125	dir=1	step=3.90625
# state=0	centroid=(4071.4,4056.79)	ellipticity=1.45361	angle=75.1062	radius=122.338	frac=0.125747	input_frac=0.125	dir=1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.15	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.15	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.15	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.15	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=157.494	frac=0.0875839	input_frac=0.15	dir=1	step=62.5
# state=-1	centroid=(4084.29,4085.4)	ellipticity=1.36821	angle=63.5735	radius=126.244	frac=0.183212	input_frac=0.15	dir=-1	step=31.25
# state=-1	centroid=(4079.55,4075.16)	ellipticity=1.40518	angle=66.0509	radius=141.869	frac=0.136983	input_frac=0.15	dir=1	step=15.625
# state=-1	centroid=(4077.04,4069.73)	ellipticity=1.41285	angle=67.8971	radius=134.056	frac=0.155735	input_frac=0.15	dir=-1	step=7.8125
# state=-1	centroid=(4075.18,4065.65)	ellipticity=1.41921	angle=69.9032	radius=137.963	frac=0.144686	input_frac=0.15	dir=1	step=3.90625
# state=-1	centroid=(4074.12,4063.81)	ellipticity=1.41611	angle=71.3069	radius=141.869	frac=0.148631	input_frac=0.15	dir=1	step=3.90625
# state=-1	centroid=(4073.6,4063.56)	ellipticity=1.40869	angle=72.3687	radius=139.916	frac=0.153174	input_frac=0.15	dir=-1	step=1.95312
# state=-1	centroid=(4073.14,4063.15)	ellipticity=1.40623	angle=73.414	radius=137.963	frac=0.151215	input_frac=0.15	dir=-1	step=1.95312
# state=-1	centroid=(4072.66,4062.63)	ellipticity=1.40579	angle=74.2903	radius=138.939	frac=0.148871	input_frac=0.15	dir=1	step=0.976562
# state=0	centroid=(4072.38,4062.48)	ellipticity=1.40312	angle=74.9329	radius=138.939	frac=0.150006	input_frac=0.15	dir=1	step=0.976562
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.175	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.175	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.175	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=94.9939	frac=0.192524	input_frac=0.175	dir=-1	step=125
# state=-1	centroid=(4090.48,4098.63)	ellipticity=1.31128	angle=61.5026	radius=157.494	frac=0.0875839	input_frac=0.175	dir=1	step=62.5
# state=-1	centroid=(4084.29,4085.4)	ellipticity=1.36821	angle=63.5735	radius=126.244	frac=0.183212	input_frac=0.175	dir=-1	step=31.25
# state=-1	centroid=(4079.55,4075.16)	ellipticity=1.40518	angle=66.0509	radius=141.869	frac=0.136983	input_frac=0.175	dir=1	step=15.625
# state=-1	centroid=(4077.04,4069.73)	ellipticity=1.41285	angle=67.8971	radius=157.494	frac=0.155735	input_frac=0.175	dir=1	step=15.625
# state=-1	centroid=(4076.55,4069.19)	ellipticity=1.39718	angle=68.8389	radius=173.119	frac=0.172689	input_frac=0.175	dir=1	step=15.625
# state=-1	centroid=(4077.37,4072.03)	ellipticity=1.36911	angle=69.2284	radius=165.306	frac=0.190939	input_frac=0.175	dir=-1	step=7.8125
# state=-1	centroid=(4077.22,4072.07)	ellipticity=1.36184	angle=69.6356	radius=157.494	frac=0.184899	input_frac=0.175	dir=-1	step=7.8125
# state=-1	centroid=(4076.58,4070.69)	ellipticity=1.36491	angle=70.1346	radius=149.681	frac=0.176583	input_frac=0.175	dir=-1	step=7.8125
# state=-1	centroid=(4075.7,4068.75)	ellipticity=1.3757	angle=70.7946	radius=153.588	frac=0.1671	input_frac=0.175	dir=1	step=3.90625
# state=-1	centroid=(4075.42,4068.38)	ellipticity=1.37524	angle=71.1192	radius=157.494	frac=0.170474	input_frac=0.175	dir=1	step=3.90625
# state=0	centroid=(4075.52,4068.89)	ellipticity=1.37009	angle=71.3918	radius=157.494	frac=0.17516	input_frac=0.175	dir=1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.2	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.2	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.2	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.2	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=217.506	frac=0.325736	input_frac=0.2	dir=-1	step=62.5
# state=-1	centroid=(4089.52,4098.04)	ellipticity=1.30276	angle=65.3499	radius=155.006	frac=0.259663	input_frac=0.2	dir=-1	step=62.5
# state=-1	centroid=(4083.58,4084.81)	ellipticity=1.36324	angle=66.1407	radius=186.256	frac=0.180411	input_frac=0.2	dir=1	step=31.25
# state=-1	centroid=(4082.11,4082.09)	ellipticity=1.36633	angle=66.7034	radius=170.631	frac=0.211949	input_frac=0.2	dir=-1	step=15.625
# state=-1	centroid=(4080.13,4077.88)	ellipticity=1.37365	angle=67.2735	radius=178.444	frac=0.19362	input_frac=0.2	dir=1	step=7.8125
# state=-1	centroid=(4079.74,4077.29)	ellipticity=1.36343	angle=67.6788	radius=178.444	frac=0.201526	input_frac=0.2	dir=1	step=7.8125
# state=-1	centroid=(4079.52,4077.08)	ellipticity=1.35525	angle=67.9983	radius=174.537	frac=0.201526	input_frac=0.2	dir=-1	step=3.90625
# state=-1	centroid=(4079.09,4076.34)	ellipticity=1.35214	angle=68.3266	radius=176.49	frac=0.197697	input_frac=0.2	dir=1	step=1.95312
# state=0	centroid=(4079.02,4076.34)	ellipticity=1.34658	angle=68.5182	radius=176.49	frac=0.200274	input_frac=0.2	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.225	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.225	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.225	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.225	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=217.506	frac=0.325736	input_frac=0.225	dir=-1	step=62.5
# state=-1	centroid=(4089.52,4098.04)	ellipticity=1.30276	angle=65.3499	radius=155.006	frac=0.259663	input_frac=0.225	dir=-1	step=62.5
# state=-1	centroid=(4083.58,4084.81)	ellipticity=1.36324	angle=66.1407	radius=186.256	frac=0.180411	input_frac=0.225	dir=1	step=31.25
# state=-1	centroid=(4082.11,4082.09)	ellipticity=1.36633	angle=66.7034	radius=217.506	frac=0.211949	input_frac=0.225	dir=1	step=31.25
# state=-1	centroid=(4083.42,4086.14)	ellipticity=1.3496	angle=67.5941	radius=201.881	frac=0.244127	input_frac=0.225	dir=-1	step=15.625
# state=-1	centroid=(4082.93,4085.57)	ellipticity=1.35032	angle=67.9768	radius=186.256	frac=0.230229	input_frac=0.225	dir=-1	step=15.625
# state=-1	centroid=(4081.67,4082.59)	ellipticity=1.35823	angle=67.9942	radius=194.069	frac=0.213142	input_frac=0.225	dir=1	step=7.8125
# state=-1	centroid=(4081.6,4082.54)	ellipticity=1.35463	angle=68.1127	radius=201.881	frac=0.220333	input_frac=0.225	dir=1	step=7.8125
# state=-1	centroid=(4082.09,4083.95)	ellipticity=1.34914	angle=68.3855	radius=197.975	frac=0.229055	input_frac=0.225	dir=-1	step=3.90625
# state=0	centroid=(4082.04,4083.98)	ellipticity=1.34922	angle=68.4836	radius=197.975	frac=0.22562	input_frac=0.225	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.25	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.25	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.25	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.25	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=217.506	frac=0.325736	input_frac=0.25	dir=-1	step=62.5
# state=-1	centroid=(4089.52,4098.04)	ellipticity=1.30276	angle=65.3499	radius=155.006	frac=0.259663	input_frac=0.25	dir=-1	step=62.5
# state=-1	centroid=(4083.58,4084.81)	ellipticity=1.36324	angle=66.1407	radius=186.256	frac=0.180411	input_frac=0.25	dir=1	step=31.25
# state=-1	centroid=(4082.11,4082.09)	ellipticity=1.36633	angle=66.7034	radius=217.506	frac=0.211949	input_frac=0.25	dir=1	step=31.25
# state=-1	centroid=(4083.42,4086.14)	ellipticity=1.3496	angle=67.5941	radius=248.756	frac=0.244127	input_frac=0.25	dir=1	step=31.25
# state=-1	centroid=(4086.29,4092.73)	ellipticity=1.32673	angle=68.0267	radius=233.131	frac=0.277935	input_frac=0.25	dir=-1	step=15.625
# state=-1	centroid=(4086.37,4093.36)	ellipticity=1.32923	angle=68.3548	radius=217.506	frac=0.265669	input_frac=0.25	dir=-1	step=15.625
# state=-1	centroid=(4085.16,4091.33)	ellipticity=1.34023	angle=68.5692	radius=217.506	frac=0.248212	input_frac=0.25	dir=-1	step=15.625
# state=-1	centroid=(4084.57,4090.37)	ellipticity=1.34478	angle=68.8022	radius=225.319	frac=0.248212	input_frac=0.25	dir=1	step=7.8125
# state=-1	centroid=(4084.85,4091.07)	ellipticity=1.34259	angle=69.0189	radius=221.412	frac=0.255489	input_frac=0.25	dir=-1	step=3.90625
# state=-1	centroid=(4084.69,4090.86)	ellipticity=1.34403	angle=69.151	radius=217.506	frac=0.25191	input_frac=0.25	dir=-1	step=3.90625
# state=-1	centroid=(4084.34,4090.2)	ellipticity=1.3466	angle=69.1885	radius=219.459	frac=0.247778	input_frac=0.25	dir=1	step=1.95312
# state=0	centroid=(4084.25,4090.1)	ellipticity=1.34623	angle=69.28	radius=219.459	frac=0.249351	input_frac=0.25	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.275	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.275	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.275	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.275	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=217.506	frac=0.325736	input_frac=0.275	dir=-1	step=62.5
# state=-1	centroid=(4089.52,4098.04)	ellipticity=1.30276	angle=65.3499	radius=248.756	frac=0.259663	input_frac=0.275	dir=1	step=31.25
# state=-1	centroid=(4089.28,4097.87)	ellipticity=1.30708	angle=66.2549	radius=233.131	frac=0.28508	input_frac=0.275	dir=-1	step=15.625
# state=-1	centroid=(4087.94,4095.67)	ellipticity=1.3216	angle=66.9599	radius=240.944	frac=0.268696	input_frac=0.275	dir=1	step=7.8125
# state=0	centroid=(4087.85,4095.76)	ellipticity=1.32325	angle=67.4507	radius=240.944	frac=0.274664	input_frac=0.275	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.3	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.3	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.3	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.3	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=217.506	frac=0.325736	input_frac=0.3	dir=-1	step=62.5
# state=-1	centroid=(4089.52,4098.04)	ellipticity=1.30276	angle=65.3499	radius=248.756	frac=0.259663	input_frac=0.3	dir=1	step=31.25
# state=-1	centroid=(4089.28,4097.87)	ellipticity=1.30708	angle=66.2549	radius=280.006	frac=0.28508	input_frac=0.3	dir=1	step=31.25
# state=-1	centroid=(4091.07,4101.6)	ellipticity=1.29145	angle=66.6485	radius=264.381	frac=0.314265	input_frac=0.3	dir=-1	step=15.625
# state=-1	centroid=(4090.86,4101.35)	ellipticity=1.2922	angle=66.8858	radius=248.756	frac=0.301947	input_frac=0.3	dir=-1	step=15.625
# state=-1	centroid=(4089.74,4099.35)	ellipticity=1.30329	angle=67.1587	radius=256.569	frac=0.286714	input_frac=0.3	dir=1	step=7.8125
# state=-1	centroid=(4089.73,4099.45)	ellipticity=1.30294	angle=67.3263	radius=264.381	frac=0.292901	input_frac=0.3	dir=1	step=7.8125
# state=-1	centroid=(4090.2,4100.42)	ellipticity=1.29822	angle=67.3979	radius=264.381	frac=0.301043	input_frac=0.3	dir=1	step=7.8125
# state=-1	centroid=(4090.42,4100.85)	ellipticity=1.29568	angle=67.4013	radius=260.475	frac=0.301043	input_frac=0.3	dir=-1	step=3.90625
# state=-1	centroid=(4090.26,4100.54)	ellipticity=1.29676	angle=67.4491	radius=262.428	frac=0.297615	input_frac=0.3	dir=1	step=1.95312
# state=0	centroid=(4090.3,4100.66)	ellipticity=1.29573	angle=67.4503	radius=262.428	frac=0.299465	input_frac=0.3	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.325	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.325	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.325	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.325	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=280.006	frac=0.322424	input_frac=0.325	dir=1	step=125
# state=-1	centroid=(4093.66,4105.7)	ellipticity=1.25949	angle=64.8884	radius=405.006	frac=0.322424	input_frac=0.325	dir=1	step=125
# state=-1	centroid=(4102.95,4119.52)	ellipticity=1.2243	angle=61.8639	radius=342.506	frac=0.431255	input_frac=0.325	dir=-1	step=62.5
# state=-1	centroid=(4102.82,4118.18)	ellipticity=1.23394	angle=60.0913	radius=280.006	frac=0.385834	input_frac=0.325	dir=-1	step=62.5
# state=-1	centroid=(4097.42,4110.33)	ellipticity=1.26535	angle=61.9079	radius=217.506	frac=0.326094	input_frac=0.325	dir=-1	step=62.5
# state=-1	centroid=(4090.73,4099.27)	ellipticity=1.32154	angle=64.0054	radius=248.756	frac=0.258411	input_frac=0.325	dir=1	step=31.25
# state=-1	centroid=(4089.83,4098.24)	ellipticity=1.3223	angle=65.2514	radius=280.006	frac=0.283482	input_frac=0.325	dir=1	step=31.25
# state=-1	centroid=(4091.34,4101.62)	ellipticity=1.30199	angle=65.896	radius=311.256	frac=0.312793	input_frac=0.325	dir=1	step=31.25
# state=-1	centroid=(4094.26,4107.2)	ellipticity=1.28092	angle=65.8181	radius=295.631	frac=0.344483	input_frac=0.325	dir=-1	step=15.625
# state=-1	centroid=(4094.32,4107.54)	ellipticity=1.27667	angle=65.8399	radius=280.006	frac=0.333468	input_frac=0.325	dir=-1	step=15.625
# state=-1	centroid=(4093.26,4105.63)	ellipticity=1.28029	angle=66.0789	radius=287.819	frac=0.319199	input_frac=0.325	dir=1	step=7.8125
# state=-1	centroid=(4093.3,4105.85)	ellipticity=1.27709	angle=66.2263	radius=287.819	frac=0.326237	input_frac=0.325	dir=1	step=7.8125
# state=-1	centroid=(4093.32,4105.96)	ellipticity=1.27495	angle=66.3035	radius=283.912	frac=0.326237	input_frac=0.325	dir=-1	step=3.90625
# state=-1	centroid=(4093.06,4105.5)	ellipticity=1.2753	angle=66.4277	radius=285.865	frac=0.322788	input_frac=0.325	dir=1	step=1.95312
# state=0	centroid=(4093.08,4105.59)	ellipticity=1.2741	angle=66.4902	radius=285.865	frac=0.324647	input_frac=0.325	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.35	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.35	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.35	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.35	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=405.006	frac=0.325736	input_frac=0.35	dir=1	step=125
# state=-1	centroid=(4103.55,4120.12)	ellipticity=1.21759	angle=61.0062	radius=342.506	frac=0.433338	input_frac=0.35	dir=-1	step=62.5
# state=-1	centroid=(4103.15,4118.45)	ellipticity=1.23035	angle=59.5107	radius=280.006	frac=0.386843	input_frac=0.35	dir=-1	step=62.5
# state=-1	centroid=(4097.55,4110.48)	ellipticity=1.26303	angle=61.5927	radius=311.256	frac=0.326574	input_frac=0.35	dir=1	step=31.25
# state=-1	centroid=(4097.62,4111.04)	ellipticity=1.26465	angle=62.1919	radius=295.631	frac=0.351126	input_frac=0.35	dir=-1	step=15.625
# state=-1	centroid=(4096.17,4109.26)	ellipticity=1.2712	angle=63.1503	radius=303.444	frac=0.336345	input_frac=0.35	dir=1	step=7.8125
# state=-1	centroid=(4096.09,4109.49)	ellipticity=1.27084	angle=63.7145	radius=311.256	frac=0.342505	input_frac=0.35	dir=1	step=7.8125
# state=0	centroid=(4096.7,4110.55)	ellipticity=1.26783	angle=63.7438	radius=311.256	frac=0.350343	input_frac=0.35	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.375	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.375	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.375	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.375	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=405.006	frac=0.325736	input_frac=0.375	dir=1	step=125
# state=-1	centroid=(4103.55,4120.12)	ellipticity=1.21759	angle=61.0062	radius=342.506	frac=0.433338	input_frac=0.375	dir=-1	step=62.5
# state=-1	centroid=(4103.15,4118.45)	ellipticity=1.23035	angle=59.5107	radius=280.006	frac=0.386843	input_frac=0.375	dir=-1	step=62.5
# state=-1	centroid=(4097.55,4110.48)	ellipticity=1.26303	angle=61.5927	radius=311.256	frac=0.326574	input_frac=0.375	dir=1	step=31.25
# state=-1	centroid=(4097.62,4111.04)	ellipticity=1.26465	angle=62.1919	radius=342.506	frac=0.351126	input_frac=0.375	dir=1	step=31.25
# state=-1	centroid=(4100.32,4114.61)	ellipticity=1.25521	angle=61.0204	radius=326.881	frac=0.379075	input_frac=0.375	dir=-1	step=15.625
# state=-1	centroid=(4100.27,4114.4)	ellipticity=1.25738	angle=60.685	radius=334.694	frac=0.367027	input_frac=0.375	dir=1	step=7.8125
# state=-1	centroid=(4100.98,4115.14)	ellipticity=1.25646	angle=60.092	radius=342.506	frac=0.373834	input_frac=0.375	dir=1	step=7.8125
# state=-1	centroid=(4101.99,4116.23)	ellipticity=1.2541	angle=59.3137	radius=338.6	frac=0.381088	input_frac=0.375	dir=-1	step=3.90625
# state=-1	centroid=(4102.16,4116.26)	ellipticity=1.25518	angle=58.9202	radius=334.694	frac=0.378161	input_frac=0.375	dir=-1	step=3.90625
# state=0	centroid=(4101.95,4115.85)	ellipticity=1.25746	angle=58.7965	radius=334.694	frac=0.374271	input_frac=0.375	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.4	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.4	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.4	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.4	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=405.006	frac=0.325736	input_frac=0.4	dir=1	step=125
# state=-1	centroid=(4103.55,4120.12)	ellipticity=1.21759	angle=61.0062	radius=342.506	frac=0.433338	input_frac=0.4	dir=-1	step=62.5
# state=-1	centroid=(4103.15,4118.45)	ellipticity=1.23035	angle=59.5107	radius=373.756	frac=0.386843	input_frac=0.4	dir=1	step=31.25
# state=-1	centroid=(4105.17,4121.05)	ellipticity=1.22744	angle=58.011	radius=358.131	frac=0.412279	input_frac=0.4	dir=-1	step=15.625
# state=-1	centroid=(4105.05,4120.39)	ellipticity=1.23438	angle=57.2939	radius=358.131	frac=0.398772	input_frac=0.4	dir=-1	step=15.625
# state=-1	centroid=(4105.05,4120.07)	ellipticity=1.239	angle=56.8892	radius=365.944	frac=0.398772	input_frac=0.4	dir=1	step=7.8125
# state=-1	centroid=(4105.59,4120.73)	ellipticity=1.23924	angle=56.4684	radius=362.037	frac=0.404882	input_frac=0.4	dir=-1	step=3.90625
# state=-1	centroid=(4105.57,4120.52)	ellipticity=1.24129	angle=56.264	radius=358.131	frac=0.401632	input_frac=0.4	dir=-1	step=3.90625
# state=-1	centroid=(4105.32,4120.03)	ellipticity=1.24432	angle=56.2413	radius=360.084	frac=0.39794	input_frac=0.4	dir=1	step=1.95312
# state=0	centroid=(4105.35,4120.02)	ellipticity=1.24529	angle=56.186	radius=360.084	frac=0.399035	input_frac=0.4	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.425	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.425	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.425	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.425	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=405.006	frac=0.325736	input_frac=0.425	dir=1	step=125
# state=-1	centroid=(4103.55,4120.12)	ellipticity=1.21759	angle=61.0062	radius=342.506	frac=0.433338	input_frac=0.425	dir=-1	step=62.5
# state=-1	centroid=(4103.15,4118.45)	ellipticity=1.23035	angle=59.5107	radius=373.756	frac=0.386843	input_frac=0.425	dir=1	step=31.25
# state=-1	centroid=(4105.17,4121.05)	ellipticity=1.22744	angle=58.011	radius=405.006	frac=0.412279	input_frac=0.425	dir=1	step=31.25
# state=-1	centroid=(4108.09,4124.9)	ellipticity=1.21506	angle=56.4504	radius=389.381	frac=0.438679	input_frac=0.425	dir=-1	step=15.625
# state=-1	centroid=(4108.3,4124.89)	ellipticity=1.21543	angle=55.5432	radius=373.756	frac=0.428444	input_frac=0.425	dir=-1	step=15.625
# state=-1	centroid=(4107.46,4123.45)	ellipticity=1.22273	angle=55.2811	radius=381.569	frac=0.415514	input_frac=0.425	dir=1	step=7.8125
# state=-1	centroid=(4107.65,4123.59)	ellipticity=1.22356	angle=55.0649	radius=389.381	frac=0.420847	input_frac=0.425	dir=1	step=7.8125
# state=-1	centroid=(4108.22,4124.34)	ellipticity=1.22081	angle=54.7349	radius=385.475	frac=0.427118	input_frac=0.425	dir=-1	step=3.90625
# state=0	centroid=(4108.22,4124.27)	ellipticity=1.22125	angle=54.6125	radius=385.475	frac=0.424378	input_frac=0.425	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.45	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.45	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=155.006	frac=0.470916	input_frac=0.45	dir=-1	step=250
# state=-1	centroid=(4096.85,4110.31)	ellipticity=1.22323	angle=62.3503	radius=280.006	frac=0.192524	input_frac=0.45	dir=1	step=125
# state=-1	centroid=(4094.74,4107.19)	ellipticity=1.24693	angle=63.8768	radius=405.006	frac=0.325736	input_frac=0.45	dir=1	step=125
# state=-1	centroid=(4103.55,4120.12)	ellipticity=1.21759	angle=61.0062	radius=530.006	frac=0.433338	input_frac=0.45	dir=1	step=125
# state=-1	centroid=(4113.78,4134.27)	ellipticity=1.17505	angle=57.4954	radius=467.506	frac=0.534237	input_frac=0.45	dir=-1	step=62.5
# state=-1	centroid=(4115.07,4134.61)	ellipticity=1.16362	angle=54.4425	radius=405.006	frac=0.49717	input_frac=0.45	dir=-1	step=62.5
# state=-1	centroid=(4112.27,4129.99)	ellipticity=1.18029	angle=53.4008	radius=405.006	frac=0.446902	input_frac=0.45	dir=-1	step=62.5
# state=-1	centroid=(4111.26,4128.25)	ellipticity=1.18917	angle=52.9809	radius=436.256	frac=0.446902	input_frac=0.45	dir=1	step=31.25
# state=-1	centroid=(4112.78,4129.98)	ellipticity=1.18224	angle=52.0478	radius=420.631	frac=0.470135	input_frac=0.45	dir=-1	step=15.625
# state=-1	centroid=(4112.48,4129.38)	ellipticity=1.18437	angle=51.762	radius=405.006	frac=0.459153	input_frac=0.45	dir=-1	step=15.625
# state=-1	centroid=(4111.41,4127.94)	ellipticity=1.19172	angle=51.973	radius=412.819	frac=0.446299	input_frac=0.45	dir=1	step=7.8125
# state=-1	centroid=(4111.49,4128.02)	ellipticity=1.19285	angle=52.0055	radius=408.912	frac=0.451313	input_frac=0.45	dir=-1	step=3.90625
# state=-1	centroid=(4111.25,4127.73)	ellipticity=1.19508	angle=52.1209	radius=410.865	frac=0.448027	input_frac=0.45	dir=1	step=1.95312
# state=0	centroid=(4111.27,4127.77)	ellipticity=1.1957	angle=52.1598	radius=410.865	frac=0.449137	input_frac=0.45	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.475	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.475	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.475	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=467.506	frac=0.560078	input_frac=0.475	dir=-1	step=62.5
# state=-1	centroid=(4116.25,4137.31)	ellipticity=1.10477	angle=51.092	radius=405.006	frac=0.512755	input_frac=0.475	dir=-1	step=62.5
# state=-1	centroid=(4113.2,4131.39)	ellipticity=1.14056	angle=51.1023	radius=436.256	frac=0.459211	input_frac=0.475	dir=1	step=31.25
# state=-1	centroid=(4113.74,4131.38)	ellipticity=1.14998	angle=50.4131	radius=420.631	frac=0.478145	input_frac=0.475	dir=-1	step=15.625
# state=-1	centroid=(4113.05,4130.1)	ellipticity=1.16281	angle=50.5622	radius=428.444	frac=0.464275	input_frac=0.475	dir=1	step=7.8125
# state=-1	centroid=(4113.19,4130.13)	ellipticity=1.1678	angle=50.4826	radius=436.256	frac=0.468371	input_frac=0.475	dir=1	step=7.8125
# state=-1	centroid=(4113.68,4130.7)	ellipticity=1.16833	angle=50.2835	radius=444.069	frac=0.473789	input_frac=0.475	dir=1	step=7.8125
# state=-1	centroid=(4114.31,4131.5)	ellipticity=1.1665	angle=49.9592	radius=440.162	frac=0.479934	input_frac=0.475	dir=-1	step=3.90625
# state=-1	centroid=(4114.34,4131.46)	ellipticity=1.16696	angle=49.8388	radius=436.256	frac=0.477263	input_frac=0.475	dir=-1	step=3.90625
# state=-1	centroid=(4114.11,4131.14)	ellipticity=1.1685	angle=49.8718	radius=436.256	frac=0.47384	input_frac=0.475	dir=-1	step=3.90625
# state=-1	centroid=(4114.04,4131.03)	ellipticity=1.16955	angle=49.9048	radius=438.209	frac=0.47384	input_frac=0.475	dir=1	step=1.95312
# state=0	centroid=(4114.13,4131.13)	ellipticity=1.16947	angle=49.8714	radius=438.209	frac=0.475228	input_frac=0.475	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.5	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.5	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.5	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=467.506	frac=0.560078	input_frac=0.5	dir=-1	step=62.5
# state=-1	centroid=(4116.25,4137.31)	ellipticity=1.10477	angle=51.092	radius=405.006	frac=0.512755	input_frac=0.5	dir=-1	step=62.5
# state=-1	centroid=(4113.2,4131.39)	ellipticity=1.14056	angle=51.1023	radius=436.256	frac=0.459211	input_frac=0.5	dir=1	step=31.25
# state=-1	centroid=(4113.74,4131.38)	ellipticity=1.14998	angle=50.4131	radius=467.506	frac=0.478145	input_frac=0.5	dir=1	step=31.25
# state=-1	centroid=(4115.44,4133.66)	ellipticity=1.14751	angle=49.6935	radius=451.881	frac=0.501006	input_frac=0.5	dir=-1	step=15.625
# state=-1	centroid=(4115.36,4133.27)	ellipticity=1.15117	angle=49.3964	radius=459.694	frac=0.489656	input_frac=0.5	dir=1	step=7.8125
# state=-1	centroid=(4115.67,4133.68)	ellipticity=1.15121	angle=49.1745	radius=467.506	frac=0.495057	input_frac=0.5	dir=1	step=7.8125
# state=-1	centroid=(4116.13,4134.4)	ellipticity=1.14933	angle=48.9861	radius=463.6	frac=0.501102	input_frac=0.5	dir=-1	step=3.90625
# state=-1	centroid=(4116.14,4134.37)	ellipticity=1.14931	angle=48.8719	radius=465.553	frac=0.498492	input_frac=0.5	dir=1	step=1.95312
# state=0	centroid=(4116.22,4134.5)	ellipticity=1.14884	angle=48.8027	radius=465.553	frac=0.500065	input_frac=0.5	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.525	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.525	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.525	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=467.506	frac=0.560078	input_frac=0.525	dir=-1	step=62.5
# state=-1	centroid=(4116.25,4137.31)	ellipticity=1.10477	angle=51.092	radius=498.756	frac=0.512755	input_frac=0.525	dir=1	step=31.25
# state=-1	centroid=(4117.47,4138.46)	ellipticity=1.11376	angle=49.9734	radius=483.131	frac=0.532449	input_frac=0.525	dir=-1	step=15.625
# state=-1	centroid=(4117.36,4137.6)	ellipticity=1.12243	angle=49.3197	radius=490.944	frac=0.519592	input_frac=0.525	dir=1	step=7.8125
# state=-1	centroid=(4117.64,4137.75)	ellipticity=1.12677	angle=49.014	radius=498.756	frac=0.523881	input_frac=0.525	dir=1	step=7.8125
# state=-1	centroid=(4118,4138.29)	ellipticity=1.12868	angle=48.9341	radius=494.85	frac=0.528877	input_frac=0.525	dir=-1	step=3.90625
# state=0	centroid=(4117.99,4138.18)	ellipticity=1.13065	angle=48.8708	radius=494.85	frac=0.525447	input_frac=0.525	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.55	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.55	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.55	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=467.506	frac=0.560078	input_frac=0.55	dir=-1	step=62.5
# state=-1	centroid=(4116.25,4137.31)	ellipticity=1.10477	angle=51.092	radius=498.756	frac=0.512755	input_frac=0.55	dir=1	step=31.25
# state=-1	centroid=(4117.47,4138.46)	ellipticity=1.11376	angle=49.9734	radius=530.006	frac=0.532449	input_frac=0.55	dir=1	step=31.25
# state=-1	centroid=(4118.84,4140.98)	ellipticity=1.11578	angle=49.8444	radius=514.381	frac=0.553229	input_frac=0.55	dir=-1	step=15.625
# state=-1	centroid=(4118.82,4140.66)	ellipticity=1.11998	angle=49.6434	radius=522.194	frac=0.542181	input_frac=0.55	dir=1	step=7.8125
# state=-1	centroid=(4119.06,4141.06)	ellipticity=1.12174	angle=49.631	radius=530.006	frac=0.546942	input_frac=0.55	dir=1	step=7.8125
# state=-1	centroid=(4119.38,4141.74)	ellipticity=1.1218	angle=49.7075	radius=526.1	frac=0.552138	input_frac=0.55	dir=-1	step=3.90625
# state=0	centroid=(4119.36,4141.67)	ellipticity=1.12255	angle=49.7372	radius=526.1	frac=0.549317	input_frac=0.55	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.575	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.575	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.575	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=655.006	frac=0.560078	input_frac=0.575	dir=1	step=125
# state=-1	centroid=(4120.53,4147.71)	ellipticity=1.07731	angle=55.0258	radius=592.506	frac=0.643049	input_frac=0.575	dir=-1	step=62.5
# state=-1	centroid=(4121.07,4147.84)	ellipticity=1.08475	angle=53.5971	radius=530.006	frac=0.603481	input_frac=0.575	dir=-1	step=62.5
# state=-1	centroid=(4119.86,4144.51)	ellipticity=1.09866	angle=51.7675	radius=561.256	frac=0.55903	input_frac=0.575	dir=1	step=31.25
# state=-1	centroid=(4120.39,4145.09)	ellipticity=1.10316	angle=51.1753	radius=545.631	frac=0.577937	input_frac=0.575	dir=-1	step=15.625
# state=-1	centroid=(4120.18,4144.34)	ellipticity=1.10833	angle=50.7151	radius=553.444	frac=0.566456	input_frac=0.575	dir=1	step=7.8125
# state=-1	centroid=(4120.35,4144.49)	ellipticity=1.11056	angle=50.5288	radius=561.256	frac=0.570876	input_frac=0.575	dir=1	step=7.8125
# state=0	centroid=(4120.6,4144.93)	ellipticity=1.1112	angle=50.5158	radius=561.256	frac=0.575733	input_frac=0.575	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.6	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.6	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.6	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=655.006	frac=0.560078	input_frac=0.6	dir=1	step=125
# state=-1	centroid=(4120.53,4147.71)	ellipticity=1.07731	angle=55.0258	radius=592.506	frac=0.643049	input_frac=0.6	dir=-1	step=62.5
# state=-1	centroid=(4121.07,4147.84)	ellipticity=1.08475	angle=53.5971	radius=530.006	frac=0.603481	input_frac=0.6	dir=-1	step=62.5
# state=-1	centroid=(4119.86,4144.51)	ellipticity=1.09866	angle=51.7675	radius=561.256	frac=0.55903	input_frac=0.6	dir=1	step=31.25
# state=-1	centroid=(4120.39,4145.09)	ellipticity=1.10316	angle=51.1753	radius=592.506	frac=0.577937	input_frac=0.6	dir=1	step=31.25
# state=-1	centroid=(4121.18,4146.68)	ellipticity=1.10246	angle=51.2536	radius=623.756	frac=0.598422	input_frac=0.6	dir=1	step=31.25
# state=-1	centroid=(4121.95,4148.5)	ellipticity=1.09769	angle=51.9944	radius=608.131	frac=0.619452	input_frac=0.6	dir=-1	step=15.625
# state=-1	centroid=(4121.91,4148.51)	ellipticity=1.09707	angle=52.1101	radius=592.506	frac=0.610134	input_frac=0.6	dir=-1	step=15.625
# state=0	centroid=(4121.63,4147.88)	ellipticity=1.0987	angle=51.8583	radius=592.506	frac=0.599408	input_frac=0.6	dir=-1	step=15.625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.625	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=405.006	frac=0.6504	input_frac=0.625	dir=-1	step=250
# state=-1	centroid=(4110.67,4132.96)	ellipticity=1.07036	angle=58.7232	radius=530.006	frac=0.470916	input_frac=0.625	dir=1	step=125
# state=-1	centroid=(4116.31,4139.79)	ellipticity=1.08381	angle=54.0264	radius=655.006	frac=0.560078	input_frac=0.625	dir=1	step=125
# state=-1	centroid=(4120.53,4147.71)	ellipticity=1.07731	angle=55.0258	radius=592.506	frac=0.643049	input_frac=0.625	dir=-1	step=62.5
# state=-1	centroid=(4121.07,4147.84)	ellipticity=1.08475	angle=53.5971	radius=623.756	frac=0.603481	input_frac=0.625	dir=1	step=31.25
# state=-1	centroid=(4121.76,4149.07)	ellipticity=1.08546	angle=53.6407	radius=655.006	frac=0.622972	input_frac=0.625	dir=1	step=31.25
# state=-1	centroid=(4122.12,4150.62)	ellipticity=1.07943	angle=54.5509	radius=639.381	frac=0.643087	input_frac=0.625	dir=-1	step=15.625
# state=-1	centroid=(4122.1,4150.62)	ellipticity=1.07864	angle=54.7498	radius=623.756	frac=0.634362	input_frac=0.625	dir=-1	step=15.625
# state=-1	centroid=(4121.99,4150.04)	ellipticity=1.08124	angle=54.3169	radius=623.756	frac=0.623762	input_frac=0.625	dir=-1	step=15.625
# state=-1	centroid=(4121.98,4149.82)	ellipticity=1.08311	angle=54.0559	radius=631.569	frac=0.623762	input_frac=0.625	dir=1	step=7.8125
# state=-1	centroid=(4122.07,4150.03)	ellipticity=1.08293	angle=54.1323	radius=627.662	frac=0.628516	input_frac=0.625	dir=-1	step=3.90625
# state=-1	centroid=(4122.07,4149.95)	ellipticity=1.08357	angle=54.0677	radius=623.756	frac=0.626	input_frac=0.625	dir=-1	step=3.90625
# state=-1	centroid=(4122.03,4149.76)	ellipticity=1.0848	angle=53.8975	radius=625.709	frac=0.623298	input_frac=0.625	dir=1	step=1.95312
# state=0	centroid=(4122.05,4149.77)	ellipticity=1.08524	angle=53.8522	radius=625.709	frac=0.624251	input_frac=0.625	dir=1	step=1.95312
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.65	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=655.006	frac=0.654212	input_frac=0.65	dir=-1	step=250
# state=-1	centroid=(4117.53,4148.22)	ellipticity=1.03296	angle=77.6494	radius=405.006	frac=0.654212	input_frac=0.65	dir=-1	step=250
# state=-1	centroid=(4113.68,4135.94)	ellipticity=1.08495	angle=56.3099	radius=530.006	frac=0.471689	input_frac=0.65	dir=1	step=125
# state=-1	centroid=(4117.38,4140.6)	ellipticity=1.09496	angle=53.0707	radius=655.006	frac=0.557871	input_frac=0.65	dir=1	step=125
# state=-1	centroid=(4120.98,4147.86)	ellipticity=1.08524	angle=54.1085	radius=780.006	frac=0.640812	input_frac=0.65	dir=1	step=125
# state=-1	centroid=(4121.84,4152.64)	ellipticity=1.05717	angle=56.8056	radius=717.506	frac=0.719071	input_frac=0.65	dir=-1	step=62.5
# state=-1	centroid=(4121.93,4153.45)	ellipticity=1.04767	angle=59.2639	radius=655.006	frac=0.688113	input_frac=0.65	dir=-1	step=62.5
# state=-1	centroid=(4121.74,4152.34)	ellipticity=1.05274	angle=58.8263	radius=592.506	frac=0.651091	input_frac=0.65	dir=-1	step=62.5
# state=-1	centroid=(4121.32,4149.67)	ellipticity=1.06776	angle=55.3957	radius=623.756	frac=0.608486	input_frac=0.65	dir=1	step=31.25
# state=-1	centroid=(4121.65,4149.86)	ellipticity=1.07344	angle=54.8773	radius=655.006	frac=0.626466	input_frac=0.65	dir=1	step=31.25
# state=-1	centroid=(4121.96,4150.97)	ellipticity=1.07086	angle=55.6239	radius=686.256	frac=0.645586	input_frac=0.65	dir=1	step=31.25
# state=-1	centroid=(4122.1,4152.15)	ellipticity=1.06258	angle=57.0292	radius=670.631	frac=0.665843	input_frac=0.65	dir=-1	step=15.625
# state=-1	centroid=(4122.01,4152.2)	ellipticity=1.06003	angle=57.757	radius=655.006	frac=0.657837	input_frac=0.65	dir=-1	step=15.625
# state=-1	centroid=(4121.9,4151.83)	ellipticity=1.06141	angle=57.6084	radius=662.819	frac=0.648452	input_frac=0.65	dir=1	step=7.8125
# state=-1	centroid=(4121.91,4151.92)	ellipticity=1.0608	angle=57.8335	radius=658.912	frac=0.653118	input_frac=0.65	dir=-1	step=3.90625
# state=0	centroid=(4121.89,4151.85)	ellipticity=1.06112	angle=57.8301	radius=658.912	frac=0.65071	input_frac=0.65	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.675	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=780.006	frac=0.6504	input_frac=0.675	dir=1	step=125
# state=-1	centroid=(4118.24,4150.31)	ellipticity=1.02647	angle=-86.2601	radius=717.506	frac=0.731484	input_frac=0.675	dir=-1	step=62.5
# state=-1	centroid=(4120.46,4153.03)	ellipticity=1.02577	angle=84.9801	radius=655.006	frac=0.69503	input_frac=0.675	dir=-1	step=62.5
# state=-1	centroid=(4120.92,4152.41)	ellipticity=1.03305	angle=71.1183	radius=686.256	frac=0.655899	input_frac=0.675	dir=1	step=31.25
# state=-1	centroid=(4121.34,4152.98)	ellipticity=1.03602	angle=68.11	radius=686.256	frac=0.67346	input_frac=0.675	dir=1	step=31.25
# ...
# state=-1	centroid=(4121.55,4154.26)	ellipticity=1.0257	angle=76.2917	radius=725.319	frac=0.695572	input_frac=0.7	dir=1	step=7.8125
# state=0	centroid=(4121.61,4154.31)	ellipticity=1.02624	angle=74.7348	radius=725.319	frac=0.699818	input_frac=0.7	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.725	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=780.006	frac=0.6504	input_frac=0.725	dir=1	step=125
# state=-1	centroid=(4118.24,4150.31)	ellipticity=1.02647	angle=-86.2601	radius=717.506	frac=0.731484	input_frac=0.725	dir=-1	step=62.5
# state=-1	centroid=(4120.46,4153.03)	ellipticity=1.02577	angle=84.9801	radius=748.756	frac=0.69503	input_frac=0.725	dir=1	step=31.25
# state=-1	centroid=(4121.27,4154.16)	ellipticity=1.02384	angle=83.5984	radius=780.006	frac=0.71424	input_frac=0.725	dir=1	step=31.25
# state=-1	centroid=(4121.84,4154.67)	ellipticity=1.02097	angle=87.3125	radius=764.381	frac=0.733495	input_frac=0.725	dir=-1	step=15.625
# state=0	centroid=(4121.83,4154.76)	ellipticity=1.01984	angle=87.8085	radius=764.381	frac=0.725063	input_frac=0.725	dir=-1	step=15.625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.75	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=780.006	frac=0.6504	input_frac=0.75	dir=1	step=125
# state=-1	centroid=(4118.24,4150.31)	ellipticity=1.02647	angle=-86.2601	radius=905.006	frac=0.731484	input_frac=0.75	dir=1	step=125
# state=-1	centroid=(4121.8,4154.52)	ellipticity=1.03683	angle=-72.8672	radius=842.506	frac=0.808918	input_frac=0.75	dir=-1	step=62.5
# state=-1	centroid=(4122.84,4155.02)	ellipticity=1.03452	angle=-70.7467	radius=780.006	frac=0.768029	input_frac=0.75	dir=-1	step=62.5
# state=-1	centroid=(4122.24,4154.82)	ellipticity=1.02733	angle=-73.9321	radius=811.256	frac=0.731281	input_frac=0.75	dir=1	step=31.25
# state=-1	centroid=(4122.64,4154.93)	ellipticity=1.02501	angle=-73.3957	radius=795.631	frac=0.751453	input_frac=0.75	dir=-1	step=15.625
# state=-1	centroid=(4122.52,4154.88)	ellipticity=1.02249	angle=-74.5783	radius=803.444	frac=0.742705	input_frac=0.75	dir=1	step=7.8125
# state=-1	centroid=(4122.64,4154.92)	ellipticity=1.02156	angle=-74.5549	radius=811.256	frac=0.747904	input_frac=0.75	dir=1	step=7.8125
# state=-1	centroid=(4122.83,4154.97)	ellipticity=1.02158	angle=-73.5881	radius=807.35	frac=0.75279	input_frac=0.75	dir=-1	step=3.90625
# state=0	centroid=(4122.82,4154.96)	ellipticity=1.02127	angle=-73.352	radius=807.35	frac=0.750541	input_frac=0.75	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=655.006	frac=0.794198	input_frac=0.775	dir=-1	step=250
# state=-1	centroid=(4109.79,4139.93)	ellipticity=1.0315	angle=-87.3669	radius=780.006	frac=0.6504	input_frac=0.775	dir=1	step=125
# state=-1	centroid=(4118.24,4150.31)	ellipticity=1.02647	angle=-86.2601	radius=905.006	frac=0.731484	input_frac=0.775	dir=1	step=125
# state=-1	centroid=(4121.8,4154.52)	ellipticity=1.03683	angle=-72.8672	radius=842.506	frac=0.808918	input_frac=0.775	dir=-1	step=62.5
# state=-1	centroid=(4122.84,4155.02)	ellipticity=1.03452	angle=-70.7467	radius=873.756	frac=0.768029	input_frac=0.775	dir=1	step=31.25
# state=-1	centroid=(4123.28,4155.55)	ellipticity=1.03894	angle=-67.7626	radius=858.131	frac=0.787739	input_frac=0.775	dir=-1	step=15.625
# state=-1	centroid=(4123.38,4155.48)	ellipticity=1.03872	angle=-66.672	radius=842.506	frac=0.777117	input_frac=0.775	dir=-1	step=15.625
# state=-1	centroid=(4123.32,4155.28)	ellipticity=1.03583	angle=-66.4995	radius=850.319	frac=0.767646	input_frac=0.775	dir=1	step=7.8125
# state=-1	centroid=(4123.38,4155.31)	ellipticity=1.03554	angle=-66.0405	radius=858.131	frac=0.77308	input_frac=0.775	dir=1	step=7.8125
# state=-1	centroid=(4123.43,4155.41)	ellipticity=1.03687	angle=-65.4776	radius=854.225	frac=0.777925	input_frac=0.775	dir=-1	step=3.90625
# state=0	centroid=(4123.42,4155.39)	ellipticity=1.03689	angle=-65.2588	radius=854.225	frac=0.77523	input_frac=0.775	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.8	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.8	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.8	dir=-1	step=250
# state=0	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=905.006	frac=0.799924	input_frac=0.8	dir=-1	step=250
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.825	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.825	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.825	dir=-1	step=250
# state=-1	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=1030.01	frac=0.800969	input_frac=0.825	dir=1	step=125
# state=-1	centroid=(4117.35,4168.23)	ellipticity=1.06682	angle=-60.8462	radius=967.506	frac=0.872835	input_frac=0.825	dir=-1	step=62.5
# state=-1	centroid=(4120.55,4162.37)	ellipticity=1.07513	angle=-60.6792	radius=905.006	frac=0.837361	input_frac=0.825	dir=-1	step=62.5
# state=-1	centroid=(4122.19,4158.56)	ellipticity=1.07001	angle=-61.0587	radius=936.256	frac=0.797318	input_frac=0.825	dir=1	step=31.25
# state=-1	centroid=(4122.78,4157.7)	ellipticity=1.07404	angle=-60.826	radius=967.506	frac=0.817792	input_frac=0.825	dir=1	step=31.25
# state=-1	centroid=(4122.29,4158.99)	ellipticity=1.07613	angle=-60.5171	radius=951.881	frac=0.834739	input_frac=0.825	dir=-1	step=15.625
# state=0	centroid=(4122.58,4158.44)	ellipticity=1.07884	angle=-60.3307	radius=951.881	frac=0.824745	input_frac=0.825	dir=-1	step=15.625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.85	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.85	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.85	dir=-1	step=250
# state=-1	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=1030.01	frac=0.800969	input_frac=0.85	dir=1	step=125
# state=-1	centroid=(4117.35,4168.23)	ellipticity=1.06682	angle=-60.8462	radius=967.506	frac=0.872835	input_frac=0.85	dir=-1	step=62.5
# state=-1	centroid=(4120.55,4162.37)	ellipticity=1.07513	angle=-60.6792	radius=998.756	frac=0.837361	input_frac=0.85	dir=1	step=31.25
# state=-1	centroid=(4120.27,4162.95)	ellipticity=1.07473	angle=-60.5053	radius=983.131	frac=0.85219	input_frac=0.85	dir=-1	step=15.625
# state=-1	centroid=(4120.9,4161.78)	ellipticity=1.07673	angle=-60.3596	radius=990.944	frac=0.843692	input_frac=0.85	dir=1	step=7.8125
# state=-1	centroid=(4120.75,4162.06)	ellipticity=1.07654	angle=-60.2509	radius=998.756	frac=0.847384	input_frac=0.85	dir=1	step=7.8125
# state=-1	centroid=(4120.33,4162.85)	ellipticity=1.07553	angle=-60.2017	radius=994.85	frac=0.851778	input_frac=0.85	dir=-1	step=3.90625
# state=0	centroid=(4120.39,4162.73)	ellipticity=1.07578	angle=-60.185	radius=994.85	frac=0.849893	input_frac=0.85	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.875	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.875	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.875	dir=-1	step=250
# state=-1	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=1030.01	frac=0.800969	input_frac=0.875	dir=1	step=125
# state=-1	centroid=(4117.35,4168.23)	ellipticity=1.06682	angle=-60.8462	radius=1155.01	frac=0.872835	input_frac=0.875	dir=1	step=125
# state=-1	centroid=(4109.51,4183.15)	ellipticity=1.05345	angle=-60.3873	radius=1092.51	frac=0.936488	input_frac=0.875	dir=-1	step=62.5
# state=-1	centroid=(4112.24,4179.53)	ellipticity=1.05439	angle=-60.2028	radius=1030.01	frac=0.911565	input_frac=0.875	dir=-1	step=62.5
# state=-1	centroid=(4116.13,4171.45)	ellipticity=1.06458	angle=-60.6709	radius=967.506	frac=0.876816	input_frac=0.875	dir=-1	step=62.5
# state=-1	centroid=(4120.14,4163.44)	ellipticity=1.0746	angle=-60.602	radius=998.756	frac=0.838117	input_frac=0.875	dir=1	step=31.25
# state=-1	centroid=(4120.15,4163.28)	ellipticity=1.07488	angle=-60.4992	radius=1030.01	frac=0.852434	input_frac=0.875	dir=1	step=31.25
# state=-1	centroid=(4118.58,4166.37)	ellipticity=1.07036	angle=-60.3567	radius=1061.26	frac=0.86936	input_frac=0.875	dir=1	step=31.25
# state=-1	centroid=(4116.51,4170.76)	ellipticity=1.06353	angle=-60.0162	radius=1045.63	frac=0.887691	input_frac=0.875	dir=-1	step=15.625
# state=-1	centroid=(4116.68,4170.37)	ellipticity=1.06396	angle=-60.0939	radius=1030.01	frac=0.881778	input_frac=0.875	dir=-1	step=15.625
# state=-1	centroid=(4117.5,4168.57)	ellipticity=1.06662	angle=-60.2856	radius=1037.82	frac=0.873173	input_frac=0.875	dir=1	step=7.8125
# state=-1	centroid=(4117.36,4168.85)	ellipticity=1.06628	angle=-60.293	radius=1033.91	frac=0.876453	input_frac=0.875	dir=-1	step=3.90625
# state=0	centroid=(4117.52,4168.51)	ellipticity=1.06682	angle=-60.3533	radius=1033.91	frac=0.874283	input_frac=0.875	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.9	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.9	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.9	dir=-1	step=250
# state=-1	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=1030.01	frac=0.800969	input_frac=0.9	dir=1	step=125
# state=-1	centroid=(4117.35,4168.23)	ellipticity=1.06682	angle=-60.8462	radius=1155.01	frac=0.872835	input_frac=0.9	dir=1	step=125
# state=-1	centroid=(4109.51,4183.15)	ellipticity=1.05345	angle=-60.3873	radius=1092.51	frac=0.936488	input_frac=0.9	dir=-1	step=62.5
# state=-1	centroid=(4112.24,4179.53)	ellipticity=1.05439	angle=-60.2028	radius=1030.01	frac=0.911565	input_frac=0.9	dir=-1	step=62.5
# state=-1	centroid=(4116.13,4171.45)	ellipticity=1.06458	angle=-60.6709	radius=1061.26	frac=0.876816	input_frac=0.9	dir=1	step=31.25
# state=-1	centroid=(4115.79,4172.3)	ellipticity=1.06211	angle=-60.3912	radius=1092.51	frac=0.889934	input_frac=0.9	dir=1	step=31.25
# state=-1	centroid=(4114.13,4176.2)	ellipticity=1.05459	angle=-59.7731	radius=1076.88	frac=0.907541	input_frac=0.9	dir=-1	step=15.625
# state=-1	centroid=(4114.46,4175.55)	ellipticity=1.05457	angle=-59.6668	radius=1061.26	frac=0.90182	input_frac=0.9	dir=-1	step=15.625
# state=-1	centroid=(4115.31,4173.59)	ellipticity=1.05737	angle=-59.8151	radius=1069.07	frac=0.893303	input_frac=0.9	dir=1	step=7.8125
# state=-1	centroid=(4115.17,4173.87)	ellipticity=1.05683	angle=-59.729	radius=1076.88	frac=0.896481	input_frac=0.9	dir=1	step=7.8125
# state=-1	centroid=(4114.75,4174.84)	ellipticity=1.055	angle=-59.5595	radius=1076.88	frac=0.901549	input_frac=0.9	dir=1	step=7.8125
# state=-1	centroid=(4114.64,4175.14)	ellipticity=1.05422	angle=-59.4644	radius=1072.97	frac=0.901549	input_frac=0.9	dir=-1	step=3.90625
# state=0	centroid=(4114.8,4174.79)	ellipticity=1.05464	angle=-59.4793	radius=1072.97	frac=0.899543	input_frac=0.9	dir=-1	step=3.90625
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.925	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.925	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=905.006	frac=0.942749	input_frac=0.925	dir=-1	step=250
# state=-1	centroid=(4116.2,4169.19)	ellipticity=1.06481	angle=-60.9788	radius=1030.01	frac=0.800969	input_frac=0.925	dir=1	step=125
# state=-1	centroid=(4117.35,4168.23)	ellipticity=1.06682	angle=-60.8462	radius=1155.01	frac=0.872835	input_frac=0.925	dir=1	step=125
# state=-1	centroid=(4109.51,4183.15)	ellipticity=1.05345	angle=-60.3873	radius=1092.51	frac=0.936488	input_frac=0.925	dir=-1	step=62.5
# state=-1	centroid=(4112.24,4179.53)	ellipticity=1.05439	angle=-60.2028	radius=1123.76	frac=0.911565	input_frac=0.925	dir=1	step=31.25
# state=-1	centroid=(4110.51,4182.2)	ellipticity=1.0513	angle=-59.9385	radius=1108.13	frac=0.926783	input_frac=0.925	dir=-1	step=15.625
# state=-1	centroid=(4111.32,4181.08)	ellipticity=1.05107	angle=-59.7967	radius=1115.94	frac=0.920252	input_frac=0.925	dir=1	step=7.8125
# state=0	centroid=(4110.83,4181.67)	ellipticity=1.05031	angle=-59.6944	radius=1115.94	frac=0.924361	input_frac=0.925	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.95	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.95	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=1280.01	frac=0.942749	input_frac=0.95	dir=1	step=125
# state=-1	centroid=(4101.95,4197.53)	ellipticity=1.05642	angle=-61.6259	radius=1217.51	frac=0.976038	input_frac=0.95	dir=-1	step=62.5
# state=-1	centroid=(4103.47,4194.9)	ellipticity=1.05847	angle=-62.8028	radius=1155.01	frac=0.962145	input_frac=0.95	dir=-1	step=62.5
# state=-1	centroid=(4106.09,4189.9)	ellipticity=1.06093	angle=-62.3657	radius=1186.26	frac=0.941311	input_frac=0.95	dir=1	step=31.25
# state=-1	centroid=(4105.3,4191.26)	ellipticity=1.059	angle=-62.5813	radius=1170.63	frac=0.951426	input_frac=0.95	dir=-1	step=15.625
# state=-1	centroid=(4105.77,4190.35)	ellipticity=1.05948	angle=-62.4629	radius=1178.44	frac=0.94661	input_frac=0.95	dir=1	step=7.8125
# state=0	centroid=(4105.54,4190.76)	ellipticity=1.05907	angle=-62.5095	radius=1178.44	frac=0.949251	input_frac=0.95	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=0.975	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1155.01	frac=0.991671	input_frac=0.975	dir=-1	step=250
# state=-1	centroid=(4104.67,4190.92)	ellipticity=1.06149	angle=-60.1352	radius=1280.01	frac=0.942749	input_frac=0.975	dir=1	step=125
# state=-1	centroid=(4101.95,4197.53)	ellipticity=1.05642	angle=-61.6259	radius=1217.51	frac=0.976038	input_frac=0.975	dir=-1	step=62.5
# state=-1	centroid=(4103.47,4194.9)	ellipticity=1.05847	angle=-62.8028	radius=1248.76	frac=0.962145	input_frac=0.975	dir=1	step=31.25
# state=-1	centroid=(4102.84,4196.41)	ellipticity=1.05733	angle=-63.4306	radius=1280.01	frac=0.969758	input_frac=0.975	dir=1	step=31.25
# state=-1	centroid=(4101.81,4198.38)	ellipticity=1.05646	angle=-63.5191	radius=1264.38	frac=0.976822	input_frac=0.975	dir=-1	step=15.625
# state=-1	centroid=(4102.13,4197.85)	ellipticity=1.05704	angle=-63.6901	radius=1272.19	frac=0.973786	input_frac=0.975	dir=1	step=7.8125
# state=0	centroid=(4101.96,4198.18)	ellipticity=1.05679	angle=-63.7088	radius=1272.19	frac=0.975391	input_frac=0.975	dir=1	step=7.8125
# state=-1	centroid=(4086.42,4114.54)	ellipticity=1.04105	angle=-71.5654	radius=1405.01	frac=0.794198	input_frac=1	dir=1	step=500
# state=-1	centroid=(4097.65,4199.6)	ellipticity=1.05378	angle=-59.0955	radius=1905.01	frac=0.991671	input_frac=1	dir=1	step=500
# state=0	centroid=(4095.66,4207.65)	ellipticity=1.05464	angle=-63.0124	radius=1905.01	frac=1	input_frac=1	dir=1	step=500

# %%
dmlist ellipse.reg cols
# Out:
#
# --------------------------------------------------------------------------------
# Columns for Table Block REGION
# --------------------------------------------------------------------------------
#
# ColNo  Name                 Unit        Type             Range
#    1   pos(x,y)             pixel        Real8          -Inf:+Inf            sky coordinates
#    2   shape                             String[30]                          Region Shape
#    3   r[2]                 pixels       Real8(2)       -Inf:+Inf            Radii
#    4   rotang               deg          Real8          -Inf:+Inf            Rotation angle
#    5   input_fraction                    Real8          -Inf:+Inf            Requested Fraction
#    6   fraction                          Real8          -Inf:+Inf            Fraction
#    7   component                         Int2           -                    Component
#    8   state                             Int2           -                    Bit encoded state
#    9   converge                          String[100]                         Convergence criteria

# %%
dmsort ellipse.reg sort_ell.reg -fraction clob+
dmlist sort_ell.reg counts
# Out:
# 40

# %%
punlearn mkregmap 
plist mkregmap
# Out:
# Parameters for /home/kjg/cxcds_param4/mkregmap.par
#
#         infile =                  Input image file
#        regions =                  Input stack of regions
#        outfile =                  Output map file
#        (binimg = )                Output binned image
#         (coord = sky)             Image coodinate name
#       (clobber = no)              Remove outfile if it already exists?
#       (verbose = 1)               Tool chatter level
#          (mode = ql)

# %%
mkregmap infile=abell665.flux.asm \
  regions="region(ellipse.reg[#row=igrid(1:40:1)])" \
  outfile=ell.map binimg=ell.img clob+
# Out:
# mkregmap
#           infile = abell665.flux.asm
#          regions = region(ellipse.reg[#row=igrid(1:40:1)])
#          outfile = ell.map
#           binimg = ell.img
#            coord = sky
#          clobber = yes
#          verbose = 1
#             mode = ql

# %%
dmimggrad ell.map ell.grad sobel mag clob+

# %%
ds9 -geometry 1500x800 ell.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask ell.grad -nomask \
    ell.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask ell.grad -nomask \
    -saveimage png ell.png -exit

display < ell.png

# %%
#plist emodel

# %%
#emodel infile=sort_ell.reg  image= abell665.flux.asm out=emodel.img clob+ --debug

# %%
#ds9 -geometry 1500x800 \
#    abell665.flux.asm -scale log -block to 2 \
#    -cmap load sunset-in-atlantis.sao \
#    emodel.img \
#    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
#    -regions sort_ell.reg \
#    -regions select all -regions color black -regions select none  \
#    -saveimage png emodel.png -exit
#
#display < emodel.png

# %%
#dmstat emodel.img cen- sig- med-

# %%
get_sky_limits abell665.flux.asm
# Out:
# Running: get_sky_limits
#   version: 07 October 2016
# Checking binning of image: abell665.flux.asm
#   Image has 1405 x 1408 pixels
#   Pixel size is 2.0 by 2.0
#   Lower left (0.5,0.5) corner is x,y= 2656.5, 2850.5
#   Upper right (1405.5,1408.5) corner is x,y= 5466.5, 5666.5
#   DM filter is:
#     x=2656.5:5466.5:#1405,y=2850.5:5666.5:#1408
#   mkexpmap xygrid value is:
#     2656.5:5466.5:#1405,2850.5:5666.5:#1408

# %%
mkregmap infile=abell665.flux.asm \
  regions="rgrid(2656.5:5466.5:100,2850.5:5666.5:100)" \
  outfile=rgrid.map binimg=rgrid.img clob+ 
  
dmimggrad rgrid.map rgrid.grad sobel mag clob+

ds9 -geometry 1500x800 rgrid.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask rgrid.grad -nomask \
    rgrid.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask rgrid.grad -nomask \
    -saveimage png rgrid.png -exit

display < rgrid.png
# Out:
# mkregmap
#           infile = abell665.flux.asm
#          regions = rgrid(2656.5:5466.5:100,2850.5:5666.5:100)
#          outfile = rgrid.map
#           binimg = rgrid.img
#            coord = sky
#          clobber = yes
#          verbose = 1
#             mode = ql

# %%
dmstat abell665.flux.asm cen+
# Out:
# -(x, y)
#     min:	0 	      @:	( 3277.5 3485.5 )
#     max:	3.6059454265e-07 	      @:	( 4069.5 4021.5 )
# cntrd[log] :	( 720.08042887 679.07468657 )
# cntrd[phys]:	( 4095.6608577 4207.6493731 )
# sigma_cntrd:	( 0.071287455573 0.067776889412 )
#    good:	1098841
#    null:	879399

# %%
mkregmap infile=abell665.flux.asm \
  regions="pgrid(4069.5,4021.5,0:1600:100,0:360:30)" \
  outfile=pgrid.map binimg=pgrid.img clob+ 
  
dmimggrad pgrid.map pgrid.grad sobel mag clob+

ds9 -geometry 1500x800 pgrid.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask pgrid.grad -nomask \
    pgrid.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask pgrid.grad -nomask \
    -saveimage png pgrid.png -exit

display < pgrid.png
# Out:
# mkregmap
#           infile = abell665.flux.asm
#          regions = pgrid(4069.5,4021.5,0:1600:100,0:360:30)
#          outfile = pgrid.map
#           binimg = pgrid.img
#            coord = sky
#          clobber = yes
#          verbose = 1
#             mode = ql

# %%
dmcontour abell665.flux.asm \
  levels=1e-6,8e-7,5e-7,4e-7,3e-7,2.5e-7,2e-7,1.5e-7,1e-7,8e-8,5e-8,4e-8,3e-8,2e-8,1e-8,5e-9,1e-9 \
  out=cntr.reg

# %%
dmstat cntr.reg"[cols component]"
# Out:
# COMPONENT
#     min:	1 	      @:	1
#     max:	84 	      @:	124
#    mean:	45.620967742
#   sigma:	24.61660623
#     sum:	5657
#    good:	124
#    null:	0

# %%
mkregmap infile=abell665.flux.asm \
  regions="region(cntr.reg[component=igrid(1:84:1)])" \
  outfile=cntr.map binimg=cntr.img clob+ 
  
dmimggrad cntr.map cntr.grad sobel mag clob+

ds9 -geometry 1500x800 cntr.img -scale log -block to 2 -scale limits 0 2e-6 \
    -cmap load sunset-in-atlantis.sao \
    -mask color black -mask cntr.grad -nomask \
    cntr.map -scale linear -scale mode minmax -zoom to 0.5 -block to 1 \
    -cmap load $ASCDS_INSTALL/contrib/data/16_ramps.lut \
    -view info no -view panner no -view magnifier no -view buttons no -view colorbar no \
    -mask color black -mask cntr.grad -nomask \
    -saveimage png cntr.png -exit

display < cntr.png
# Out:
# mkregmap
#           infile = abell665.flux.asm
#          regions = region(cntr.reg[component=igrid(1:84:1)])
#          outfile = cntr.map
#           binimg = cntr.img
#            coord = sky
#          clobber = yes
#          verbose = 1
#             mode = ql

# %%
# same thing w/ eg vtpdetect source regions (or any of the detect outputs)
